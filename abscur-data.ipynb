# %% [markdown]
# # Источник данных для проекта "Авсолютные валютные курсы"
#
# [**Оглавление проекта**](https://docs.google.com/spreadsheets/d/1UgC2NfKtKJPaXglsmVJET7Xnp2ZtOzJgKD9DN-VGFA8/edit#gid=77497797)

# %%
import pandas as pd

# %% [markdown]
# # Импорт абсолютных валютных курсов
#
# Импортируем данные с [**листа Google-таблицы**](https://docs.google.com/spreadsheets/d/1UgC2NfKtKJPaXglsmVJET7Xnp2ZtOzJgKD9DN-VGFA8/edit#gid=1871847763). Данные на листе обновляются каждый день.

# %%
url="https://docs.google.com/spreadsheets/d/1UgC2NfKtKJPaXglsmVJET7Xnp2ZtOzJgKD9DN-VGFA8/export?format=csv&id=1UgC2NfKtKJPaXglsmVJET7Xnp2ZtOzJgKD9DN-VGFA8&gid=1871847763"
data_abs = pd.read_csv(url,index_col="Date",decimal=",",parse_dates=True)
data_abs
# Out:
#                 AUD     HKD     JPY     SEK      USD      CAD      CHF  \
# Date
# 2022-05-27  13.9259  2.4785  0.1528  1.9844  19.4366  15.2797  20.3149
# 2022-05-30  13.9348  2.4679  0.1517  1.9875  19.3578  15.2964  20.2277
# 2022-05-31  13.9177  2.4731  0.1507  1.9891  19.3854  15.3296  20.2144
# 2022-06-01  13.9625  2.4809  0.1495  1.9788  19.4540  15.3716  20.2046
# 2022-06-02  14.0753  2.4707  0.1491  1.9999  19.3754  15.4075  20.2313
# ...             ...     ...     ...     ...      ...      ...      ...
# 2022-12-12  13.9151  2.6538  0.1498  1.9975  20.6281  15.1276  22.0352
# 2022-12-13  14.0509  2.6380  0.1511  2.0093  20.4995  15.1326  22.0758
# 2022-12-14  14.0538  2.6352  0.1511  2.0166  20.4832  15.1149  22.1495
# 2022-12-15  13.8205  2.6527  0.1496  1.9950  20.6036  15.0961  22.2069
# 2022-12-16  13.8470  2.6491  0.1499  2.0011  20.5793  15.1053  22.2174
#
#                 EUR     CNY     CZK  ...     PKR     PLN     QAR     RON  \
# ...

# %% [markdown]
# # Выгрузка абсолютных курсов в файл

# %%
data_abs.to_csv("abscur.csv")
