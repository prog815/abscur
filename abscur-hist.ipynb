# %% [markdown]
# <a href="https://www.kaggle.com/code/eavprog/abscur-hist?scriptVersionId=115632846" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Графики истории абсолютных валютных курсов
#
# Для каждой валюты приводим график истории абсолютного курса. Графики строим для разных временных промежутков от месяца до 5 лет.

# %%
import numpy as np
import pandas as pd
