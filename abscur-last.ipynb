# %% [markdown]
# # Ипорт библиотек

# %%
import numpy as np
import pandas as pd

import lib_abscur_post

# %%
import os

def find(name, path):
    for root, dirs, files in os.walk(path):
        if name in files:
            return os.path.join(root, name)

# %% [markdown]
# # Предыдущая выгрузка последних

# %%
prevPostDate = 'давно'
try:
    prevPostDate = str(pd.read_csv(find('abscur_last.csv','..'),index_col=0).columns[0][-10:])
except:
    pass
prevPostDate
# Out:
# '2022-01-06'

# %% [markdown]
# # История абсолютных курсов

# %%
close_abs = pd.read_pickle(find('close_abs.pkl','..'))
close_abs
# Out:
#                   AUD        CAD       HKD       JPY       SEK        USD  \
# Date
# 2017-01-09  12.370892  12.780932  2.182068  0.144430  1.868369  16.926845
# 2017-01-10  12.430424  12.786782  2.178314  0.145652  1.871000  16.895122
# 2017-01-11  12.473410  12.795266  2.185163  0.146220  1.866941  16.950953
# 2017-01-12  12.580555  12.834056  2.178581  0.146742  1.873857  16.894341
# 2017-01-13  12.620697  12.816984  2.173750  0.146964  1.884420  16.855857
# ...               ...        ...       ...       ...       ...        ...
# 2021-12-31  13.643938  14.766722  2.413409  0.163539  2.080531  18.816999
# 2022-01-03  13.661982  14.849352  2.411210  0.163250  2.078605  18.796237
# 2022-01-04  13.547417  14.764309  2.414412  0.163222  2.068110  18.828613
# 2022-01-05  13.638900  14.830231  2.417666  0.162146  2.071702  18.840641
# 2022-01-06  13.608071  14.768840  2.417477  0.162241  2.068740  18.842780
#
#                   CHF        EUR       CNY       CZK  ...       PKR       PLN  \
# Date                                                  ...
# 2017-01-09  16.630636  17.807381  2.456761  0.659422  ...  0.161670  4.092900
# 2017-01-10  16.660139  17.887913  2.437143  0.662403  ...  0.164558  4.085773
# 2017-01-11  16.663767  17.871051  2.449636  0.661782  ...  0.163825  4.094443
# 2017-01-12  16.672780  17.893185  2.436821  0.662636  ...  0.164582  4.095896
# 2017-01-13  16.679584  17.880899  2.446340  0.662032  ...  0.162654  4.096119
# ...               ...        ...       ...       ...  ...       ...       ...
# 2021-12-31  20.589899  21.306385  2.954646  0.862039  ...  0.105743  4.641096
# 2022-01-03  20.609897  21.377106  2.958241  0.859888  ...  0.105627  4.659005
# 2022-01-04  20.498460  21.271560  2.964771  0.860390  ...  0.106950  4.653270
# 2022-01-05  20.563137  21.256934  2.962447  0.864116  ...  0.106867  4.659361
# 2022-01-06  20.538772  21.315445  2.965109  0.870408  ...  0.106849  4.664203
#
#                  QAR       RON       SAR       THB       TRY       TWD  \
# Date
# 2017-01-09  4.651766  3.961998  4.513464  0.474115  4.650449  0.528287
# 2017-01-10  4.642537  3.982069  4.510056  0.474489  4.555795  0.527923
# 2017-01-11  4.657879  3.983117  4.525444  0.477048  4.462833  0.530895
# 2017-01-12  4.642323  3.987053  4.509968  0.477107  4.360843  0.529371
# 2017-01-13  4.631748  3.988136  4.494536  0.476693  4.478879  0.531630
# ...              ...       ...       ...       ...       ...       ...
# 2021-12-31  5.169505  4.307231  5.017904  0.564651  1.415823  0.680328
# 2017-01-10  9.03428  1.43481  35.606998   3.70849  32.002998  26.544001
# 2017-01-11  9.08071  1.43706  35.533001   3.79825  31.929001  26.919001
# 2017-01-12  9.01691  1.42582  35.410000   3.87410  31.914000  26.795000
# 2017-01-13  8.94770  1.42568  35.360001   3.76341  31.705999  27.086000
# ...             ...      ...        ...       ...        ...        ...
# 2021-12-31  9.04681  1.35191  33.325001  13.29050  27.658701  27.022661
# 2022-01-03  9.04474  1.34820  33.111000  13.35660  27.702101  27.022955
# 2022-01-04  9.09965  1.35312  33.243000  13.06170  27.624701  27.028234
# 2022-01-05  9.09420  1.35571  33.241001  13.41150  27.515499  27.016205
# 2022-01-06  9.11235  1.35771  33.248001  13.68800  27.596399  27.209152
#
#              USDVND    USDZAR
# Date
# 2017-01-09  22077.0  13.74490
# 2017-01-10  22237.0  13.64450
# 2017-01-11  22059.0  13.72690
# 2017-01-12  22265.0  13.71820
# 2017-01-13  22202.0  13.52300
# ...             ...       ...
# 2021-12-31  22765.0  15.88910
# 2022-01-03  22825.0  15.92990
# 2022-01-04  22825.0  15.86150
# 2022-01-05  22752.0  15.99912
# 2022-01-06  22755.0  15.85063
#
# [1304 rows x 87 columns]

# %%
_ = lib_abscur_post.sendTable(close_par,"par_hist")

# %% [markdown]
# # Последние парные курсы

# %%
d = pd.DataFrame(index=pd.date_range(close_par.index[0],close_par.index[-1]),columns=close_par.columns)
d.loc[close_par.index.values] = close_par.values
d.fillna(method='pad',inplace=True)

df = pd.DataFrame()
df[f'курс на {close_par.index[-1]}'] = d.iloc[-1,:]
df['% изм.день'] = d.pct_change(1).iloc[-1,:]
df['% изм.неделя'] = d.pct_change(7).iloc[-1,:]
df['% изм.месяц'] = d.pct_change(30).iloc[-1,:]
df['% изм.квартал'] = d.pct_change(90).iloc[-1,:]
df['% изм.полгода'] = d.pct_change(180).iloc[-1,:]
df['% изм.год'] = d.pct_change(365).iloc[-1,:]
df
# Out:
#         курс на 2022-01-06  % изм.день  % изм.неделя  % изм.месяц  \
# AUDCAD            0.921320    0.001870     -0.006952     0.024022
# AUDHKD            5.627300   -0.002287     -0.005568     0.023352
# AUDJPY           83.848999   -0.002913      0.004986     0.048427
# AUDSEK            6.579700   -0.000996      0.004419     0.026618
# AUDUSD            0.722080   -0.002487     -0.005234     0.024343
# ...                    ...         ...           ...          ...
# USDTRY           13.688000    0.020617      0.082886    -0.006903
# USDTWD           27.596399    0.002940     -0.000760    -0.002271
# USDUAH           27.209152    0.007142      0.008413     0.003825
# USDVND        22755.000000    0.000132     -0.002848    -0.011512
# USDZAR           15.850630   -0.009281     -0.003716    -0.002923
#
#         % изм.квартал  % изм.полгода  % изм.год
# AUDCAD       0.003638      -0.010757  -0.063775
# AUDHKD      -0.012008      -0.024968  -0.065142
# AUDJPY       0.026379       0.027385   0.051807
# AUDSEK       0.024158       0.029992   0.036297
# AUDUSD      -0.013120      -0.028586  -0.070203
# ...               ...            ...        ...
# USDTRY       0.543023       0.576613   0.853790
# USDTWD      -0.013304      -0.013004  -0.012828
# USDUAH       0.043093       0.006293  -0.031512
# USDVND       0.000220      -0.010953  -0.014081
# USDZAR       0.061137       0.111347   0.060222
#
# [87 rows x 7 columns]

# %%
df.to_csv("par_last.csv")

# %%
_ = lib_abscur_post.sendTable(df,"last_par")

# %% [markdown]
# # Последние абсолютные курсы

# %%
d = pd.DataFrame(index=pd.date_range(close_abs.index[0],close_abs.index[-1]),columns=close_abs.columns)
d.loc[close_abs.index.values] = close_abs.values
d.fillna(method='pad',inplace=True)

df = pd.DataFrame()
df[f'курс на {close_abs.index[-1]}'] = close_abs.iloc[-1,:]
df['% изм.день'] = d.pct_change(1).iloc[-1,:]
df['% изм.неделя'] = d.pct_change(7).iloc[-1,:]
df['% изм.месяц'] = d.pct_change(30).iloc[-1,:]
df['% изм.квартал'] = d.pct_change(90).iloc[-1,:]
df['% изм.полгода'] = d.pct_change(180).iloc[-1,:]
df['% изм.год'] = d.pct_change(365).iloc[-1,:]
df
# Out:
#      курс на 2022-01-06  % изм.день  % изм.неделя  % изм.месяц  % изм.квартал  \
# AUD           13.608071   -0.002260     -0.002183     0.020056       0.009302
# CAD           14.768840   -0.004140      0.004797    -0.004044       0.005623
# HKD            2.417477   -0.000078      0.003197    -0.003449       0.021341
# JPY            0.162241    0.000585     -0.007240    -0.027143      -0.016847
# SEK            2.068740   -0.001430     -0.006506    -0.006339      -0.014465
# USD           18.842780    0.000114      0.002909    -0.004533       0.022582
# CHF           20.538772   -0.001185     -0.000972     0.004533       0.034987
# EUR           21.315445    0.002753     -0.001164    -0.001521       0.000918
# CNY            2.965109    0.000899      0.004270    -0.001724       0.036427
# CZK            0.870408    0.007282      0.011529     0.033217       0.038448
# GBP           25.542174    0.002106      0.007287     0.017681       0.017854
# ILS            6.084181   -0.002867      0.009316     0.016968       0.064127
# NOK            2.129282   -0.000036     -0.005747     0.023115      -0.009469
# NZD           12.801516   -0.002784     -0.003798     0.002179       0.001208
# RUB            0.245779   -0.018061     -0.032417    -0.034273      -0.042332
# SGD           13.879477   -0.001300     -0.001801     0.004094       0.022796
# ZAR            1.188875    0.009575      0.006741    -0.002028      -0.036964
# AED            5.131336    0.000114      0.002909    -0.004560       0.022610
# ARS            0.182771    0.000246     -0.001662    -0.022446      -0.019463
# BRL            3.302486   -0.005046      0.002393    -0.007609      -0.011226
# CLP            0.022485    0.010747      0.015906     0.004507      -0.009462
# COP            0.004679    0.012936      0.005200    -0.028306      -0.042512
# DKK            2.865072    0.002483     -0.001760    -0.002494       0.000811
# EGP            1.201195    0.001083      0.002353    -0.004152       0.021298
# HUF            0.058849    0.003862      0.020168     0.006909      -0.009914
# IDR            0.001304   -0.004109     -0.011635    -0.001535       0.003067
# INR            0.253161    0.001522      0.004798     0.008323       0.028076
# ISK            0.145515    0.008069      0.003916     0.000618       0.015553
# KRW            0.015712   -0.002180     -0.010120    -0.020047       0.015675
# KWD           62.378854    0.000776      0.002677    -0.003939       0.019366
# KZT            0.043522   -0.001710      0.003802     0.001821      -0.000093
# MXN            0.916313   -0.001915      0.002631     0.027417       0.027079
# MYR            4.494938   -0.001795     -0.000081     0.004491       0.019899
# PEN            4.759479   -0.000897      0.005189     0.026647       0.056418
# PHP            0.370265    0.013575      0.010299    -0.012846       0.017699
# PKR            0.106849   -0.000170      0.011155    -0.007073      -0.011630
# PLN            4.664203    0.001039      0.004143     0.002202       0.003982
# QAR            5.176588    0.000114      0.002909    -0.004669       0.022582
# RON            4.314218    0.002884     -0.000489    -0.001729       0.000855
# SAR            5.022661    0.000012      0.002494    -0.005709       0.020900
# THB            0.566734   -0.000097      0.008851     0.012893       0.039252
# TRY            1.376591   -0.020089     -0.073855     0.002387      -0.337287
# TWD            0.682798   -0.002818      0.003672    -0.002267       0.036370
# UAH            0.692516   -0.006979     -0.005458    -0.008326      -0.019664
# VND            0.000828   -0.000018      0.005774     0.007060       0.022357
#
#      % изм.полгода  % изм.год
# AUD       0.005657  -0.009842
# CAD       0.016514   0.057606
# HKD       0.031483   0.058940
# JPY      -0.021271  -0.058603
# SEK      -0.023662  -0.044534
# USD       0.034966   0.064636
# CHF       0.032122   0.019162
# EUR      -0.011421  -0.020812
# CNY       0.056353   0.080625
# CZK       0.039954   0.044331
# GBP       0.017471   0.059009
# ILS       0.096271   0.099603
# NOK       0.027288   0.018128
# NZD       0.011965  -0.003344
# RUB       0.008942   0.029926
# SGD       0.030974   0.033120
# ZAR      -0.068528   0.004494
# AED       0.034994   0.064665
# ARS      -0.036360  -0.124420
# BRL      -0.046232  -0.014020
# CLP      -0.070158  -0.116551
# COP      -0.013268  -0.089939
# DKK      -0.012169  -0.021034
# EGP       0.033396   0.063469
# HUF      -0.026303  -0.030247
# IDR       0.047303   0.026573
# INR       0.039016   0.049541
# ISK      -0.015308   0.040957
# KRW      -0.010748  -0.035502
# KWD       0.029929   0.068196
# KZT       0.023646   0.031820
# MXN       0.005644   0.030389
# MYR       0.031756   0.019684
# PEN       0.033659  -0.024644
# PHP       0.016052   0.006268
# PKR      -0.070379  -0.032681
# PLN      -0.018929  -0.029606
# QAR       0.034966   0.064636
# RON      -0.015436  -0.035890
# SAR       0.033822   0.063500
# THB       0.012615  -0.041930
# TRY      -0.343551  -0.425698
# TWD       0.048602   0.078470
# UAH       0.028494   0.099277
# VND       0.046428   0.079842

# %%
df.to_csv("abscur_last.csv")

# %% [markdown]
# # Предача последних абсолютных курсов

# %%
_ = lib_abscur_post.sendTable(df,"last_abs")

# %% [markdown]
# # Публикация через центральный сервис в каналах

# %%
import lib_abscur_post

if close_abs.index[-1] != prevPostDate:
    title = "Абсолютные курсы на " + close_abs.index[-1]
    message = ', '.join([str(cur) + " " + str(np.round(price,4)) + "(" + str(np.round(pct*100,2)) + "%)" for cur,price,pct in df.iloc[:,:2].reset_index().values])
    link = 'https://docs.google.com/spreadsheets/d/1CrNvvV-p6XG7lSJXftPKk_aY4nuH4WK25rPxaNKrM3U'
    _ = lib_abscur_post.postToChanels(title,message,link)
