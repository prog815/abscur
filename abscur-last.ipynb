# %% [markdown]
# # Ипорт библиотек

# %%
import numpy as np
import pandas as pd

import lib_abscur_post

# %%
import os

def find(name, path):
    for root, dirs, files in os.walk(path):
        if name in files:
            return os.path.join(root, name)

# %% [markdown]
# # Предыдущая выгрузка последних

# %%
prevPostDate = 'давно'
try:
    prevPostDate = str(pd.read_csv(find('abscur_last.csv','..'),index_col=0).columns[0][-10:])
except:
    pass
prevPostDate
# Out:
# '2022-05-02'

# %% [markdown]
# # История абсолютных курсов

# %%
close_abs = pd.read_pickle(find('close_abs.pkl','..'))
close_abs
# Out:
#                   AUD        CAD       HKD       JPY       SEK        USD  \
# Date
# 2017-05-03  12.434278  12.026127  2.118416  0.147173  1.874185  16.484290
# 2017-05-04  12.269759  12.034006  2.122817  0.146435  1.869066  16.517579
# 2017-05-05  12.237825  12.007312  2.121500  0.146683  1.870269  16.511978
# 2017-05-08  12.454549  12.178178  2.159902  0.236214  1.101286  16.534376
# 2017-05-09  12.437502  12.185076  2.164581  0.235608  1.101507  16.567581
# ...               ...        ...       ...       ...       ...        ...
# 2022-04-26  13.913305  15.199440  2.470221  0.151735  1.996949  19.394194
# 2022-04-27  13.907294  15.187215  2.481889  0.152975  1.979216  19.476901
# 2022-04-28  13.900680  15.204028  2.486622  0.151928  1.982678  19.522397
# 2022-04-29  13.909955  15.255383  2.494573  0.149602  1.980257  19.578214
# 2022-05-02  13.815681  15.193812  2.492198  0.150387  1.990801  19.553119
#
#                   CHF        EUR       CNY       CZK  ...       PKR       PLN  \
# Date                                                  ...
# 2017-05-03  16.631217  18.020845  2.392402  0.669606  ...  0.157518  4.293902
# 2017-05-04  16.614018  17.985206  2.396208  0.673245  ...  0.159482  4.277614
# 2017-05-05  16.742220  18.124439  2.395597  0.675935  ...  0.160529  4.288881
# 2017-05-08  18.188159  18.109012  2.408225  0.678116  ...  0.157997  4.313117
# 2017-05-09  18.077228  18.088602  2.400200  0.678954  ...  0.159872  4.277933
# ...               ...        ...       ...       ...  ...       ...       ...
# 2022-04-26  20.230587  20.735567  2.956339  0.854259  ...  0.104410  4.479095
# 2022-04-27  20.236147  20.698740  2.970800  0.847585  ...  0.103932  4.395550
# 2022-04-28  20.141769  20.552952  2.974085  0.841894  ...  0.105356  4.379041
# 2022-04-29  20.141719  20.531661  2.955249  0.839289  ...  0.105606  4.387263
# 2022-05-02  20.072920  20.595221  2.958732  0.840281  ...  0.105465  4.406337
#
#                  QAR       RON       SAR       THB       TRY       TWD  \
# Date
# 2017-05-03  4.529647  3.966479  4.400622  0.478499  4.679581  0.548781
# 2017-05-04  4.538295  3.959341  4.409980  0.478078  4.674169  0.549798
# 2017-05-05  4.537255  3.994189  4.408131  0.476894  4.646406  0.548225
# 2017-05-08  4.541662  3.994534  4.408814  0.477279  4.670160  0.548204
# 2017-05-09  4.552534  3.984411  4.422857  0.478017  4.621877  0.549578
# ...              ...       ...       ...       ...       ...       ...
# 2022-04-26  5.328807  4.205250  5.177216  0.569396  1.312911  0.664328
# 2017-05-04  8.84240  1.39723  34.549999   3.53380  30.042999  26.312000
# 2017-05-05  8.83177  1.39990  34.624001   3.55371  30.118999  26.087999
# 2017-05-08  8.82145  1.40638  34.643002   3.54043  30.160999  26.129999
# 2017-05-09  8.83772  1.40554  34.659000   3.58460  30.146000  26.292999
# ...             ...      ...        ...       ...        ...        ...
# 2022-04-26  9.71209  1.37369  34.061001  14.77190  29.193701  29.970440
# 2022-04-27  9.83790  1.37781  34.235001  14.79970  29.300699  29.999813
# 2022-04-28  9.82570  1.38077  34.348999  14.80980  29.374701  29.991417
# 2022-04-29  9.88329  1.38650  34.433998  14.78889  29.452700  29.940037
# 2022-05-02  9.81920  1.38370  34.188999  14.85490  29.434000  29.965641
#
#              USDVND    USDZAR
# Date
# 2017-05-03  22426.0  13.33780
# 2017-05-04  22280.0  13.43280
# 2017-05-05  22286.0  13.63250
# 2017-05-08  22422.0  13.45108
# 2017-05-09  22415.0  13.60702
# ...             ...       ...
# 2022-04-26  22983.0  15.67310
# 2022-04-27  22970.0  15.82465
# 2022-04-28  22965.0  15.86366
# 2022-04-29  22956.0  15.98250
# 2022-05-02  22962.0  15.79410
#
# [1304 rows x 87 columns]

# %%
_ = lib_abscur_post.sendTable(close_par,"par_hist")

# %% [markdown]
# # Последние парные курсы

# %%
d = pd.DataFrame(index=pd.date_range(close_par.index[0],close_par.index[-1]),columns=close_par.columns)
d.loc[close_par.index.values] = close_par.values
d.fillna(method='pad',inplace=True)

df = pd.DataFrame()
df[f'курс на {close_par.index[-1]}'] = d.iloc[-1,:]
df['% изм.день'] = d.pct_change(1).iloc[-1,:]
df['% изм.неделя'] = d.pct_change(7).iloc[-1,:]
df['% изм.месяц'] = d.pct_change(30).iloc[-1,:]
df['% изм.квартал'] = d.pct_change(90).iloc[-1,:]
df['% изм.полгода'] = d.pct_change(180).iloc[-1,:]
df['% изм.год'] = d.pct_change(365).iloc[-1,:]
df
# Out:
#         курс на 2022-05-02  % изм.день  % изм.неделя  % изм.месяц  \
# AUDCAD            0.908120   -0.001832     -0.013047    -0.029683
# AUDHKD            5.543580   -0.005779     -0.023386    -0.055371
# AUDJPY           91.848999   -0.011951     -0.012748     0.007227
# AUDSEK            6.939564   -0.011599      0.007875    -0.013290
# AUDUSD            0.706539   -0.006112     -0.023704    -0.056933
# ...                    ...         ...           ...          ...
# USDTRY           14.854900    0.004464      0.007310     0.012866
# USDTWD           29.434000   -0.000635      0.004196     0.028596
# USDUAH           29.965641    0.000855      0.026174     0.025254
# USDVND        22962.000000    0.000261     -0.000131     0.005430
# USDZAR           15.794100   -0.011788      0.014423     0.082129
#
#         % изм.квартал  % изм.полгода  % изм.год
# AUDCAD       0.010324      -0.015869  -0.048770
# AUDHKD       0.005831      -0.041815  -0.081820
# AUDJPY       0.128796       0.084148   0.084455
# AUDSEK       0.052216       0.088828   0.066376
# AUDUSD      -0.000412      -0.050223  -0.091575
# ...               ...            ...        ...
# USDTRY       0.117263       0.547257   0.814920
# USDTWD       0.059906       0.056554   0.060073
# USDUAH       0.064508       0.150568   0.089616
# USDVND       0.013999       0.009407  -0.003991
# USDZAR       0.029467       0.024713   0.105890
#
# [87 rows x 7 columns]

# %%
df.to_csv("par_last.csv")

# %%
_ = lib_abscur_post.sendTable(df,"last_par")

# %% [markdown]
# # Последние абсолютные курсы

# %%
d = pd.DataFrame(index=pd.date_range(close_abs.index[0],close_abs.index[-1]),columns=close_abs.columns)
d.loc[close_abs.index.values] = close_abs.values
d.fillna(method='pad',inplace=True)

df = pd.DataFrame()
df[f'курс на {close_abs.index[-1]}'] = close_abs.iloc[-1,:]
df['% изм.день'] = d.pct_change(1).iloc[-1,:]
df['% изм.неделя'] = d.pct_change(7).iloc[-1,:]
df['% изм.месяц'] = d.pct_change(30).iloc[-1,:]
df['% изм.квартал'] = d.pct_change(90).iloc[-1,:]
df['% изм.полгода'] = d.pct_change(180).iloc[-1,:]
df['% изм.год'] = d.pct_change(365).iloc[-1,:]
df
# Out:
#      курс на 2022-05-02  % изм.день  % изм.неделя  % изм.месяц  % изм.квартал  \
# AUD           13.815681   -0.006777     -0.009414    -0.028773       0.038539
# CAD           15.193812   -0.004036      0.003804     0.002131       0.026747
# HKD            2.492198   -0.000952      0.014309     0.027979       0.032598
# JPY            0.150387    0.005242      0.001975    -0.035623      -0.079852
# SEK            1.990801    0.005324     -0.015186    -0.015835      -0.013333
# USD           19.553119   -0.001282      0.014052     0.029958       0.038879
# CHF           20.072920   -0.003416     -0.005211    -0.024148      -0.011022
# EUR           20.595221    0.003096     -0.011075    -0.020069      -0.025233
# CNY            2.958732    0.001179     -0.003457    -0.012640      -0.000513
# CZK            0.840281    0.001182     -0.019407    -0.025336      -0.035627
# GBP           24.581496    0.007403     -0.006364    -0.015294      -0.028368
# ILS            5.849466   -0.004695     -0.010047    -0.014905      -0.013312
# NOK            2.082596    0.000982     -0.033802    -0.036608      -0.014707
# NZD           12.619293   -0.006616     -0.011174    -0.040991       0.019678
# RUB            0.266570   -0.014900      0.066216     0.144999       0.095870
# SGD           14.144710    0.000439      0.003965     0.007406       0.015937
# ZAR            1.238666    0.011378      0.000595    -0.048306       0.009831
# AED            5.323938   -0.001439      0.014041     0.029795       0.038871
# ARS            0.169460   -0.003151      0.003281    -0.009222      -0.053263
# BRL            3.933200   -0.008012     -0.021869    -0.018419       0.108217
# CLP            0.022949    0.005165     -0.004110    -0.049500      -0.024258
# COP            0.004942    0.002581     -0.012090    -0.020068       0.034945
# DKK            2.769642    0.002326     -0.011688    -0.019868      -0.024971
# EGP            1.058837   -0.001887      0.017198     0.017760      -0.117010
# HUF            0.054529    0.003417     -0.031127    -0.046991      -0.084129
# IDR            0.001349   -0.000455      0.004254     0.020078       0.028842
# INR            0.255519   -0.000422      0.013262     0.021695       0.012171
# ISK            0.149844    0.002009     -0.001723     0.009910       0.014358
# KRW            0.015487    0.006439     -0.001506    -0.009224      -0.008361
# KWD           63.857346   -0.000629      0.010409     0.020708       0.026326
# KZT            0.044237    0.002399      0.015120     0.091527       0.015596
# MXN            0.957670   -0.000112      0.004845     0.002608       0.049489
# MYR            4.493937    0.001128      0.007410    -0.005076      -0.000995
# PEN            5.098597   -0.003886     -0.028528    -0.000390       0.039421
# PHP            0.373650    0.003108      0.015602     0.019645       0.015652
# PKR            0.105465   -0.001336      0.013341     0.017736      -0.011384
# PLN            4.406337    0.004348     -0.019023    -0.028053      -0.045168
# QAR            5.372474   -0.001145      0.014191     0.029958       0.038879
# RON            4.172400    0.003087     -0.014403    -0.019998      -0.024922
# SAR            5.213609   -0.002443      0.013890     0.029063       0.038091
# THB            0.571913    0.005875      0.006845     0.001309       0.008645
# TRY            1.316274   -0.005720      0.006693     0.016875      -0.070157
# TWD            0.664304   -0.000647      0.009814     0.001324      -0.019838
# UAH            0.652518   -0.002135     -0.011813     0.004588      -0.024076
# VND            0.000852   -0.001543      0.014185     0.024396       0.024537
#
#      % изм.полгода  % изм.год
# AUD       0.008393  -0.007397
# CAD       0.023363   0.042217
# HKD       0.052552   0.081115
# JPY      -0.069599  -0.084784
# SEK      -0.074164  -0.069303
# USD       0.061342   0.092642
# CHF      -0.003252   0.019539
# EUR      -0.034464  -0.050773
# CNY       0.027134   0.069219
# CZK       0.006045   0.000401
# GBP      -0.020057  -0.015300
# ILS      -0.004302   0.060771
# NOK      -0.036816  -0.048148
# NZD      -0.038573  -0.026940
# RUB       0.036262   0.113351
# SGD       0.035526   0.047867
# ZAR       0.035789  -0.011119
# AED       0.061203   0.092499
# ARS      -0.081901  -0.114794
# BRL       0.212346   0.172887
# CLP       0.012585  -0.090886
# COP       0.018687   0.025560
# DKK      -0.034182  -0.050907
# EGP      -0.099487  -0.074767
# HUF      -0.081863  -0.095481
# IDR       0.046685   0.088849
# INR       0.036222   0.058126
# ISK       0.052639   0.026492
# KRW      -0.009685  -0.042280
# KWD       0.044149   0.072480
# KZT       0.022226   0.052571
# MXN       0.080207   0.071606
# MYR       0.011336   0.029610
# PEN       0.108943   0.079821
# PHP       0.019622   0.011732
# PKR      -0.026531  -0.097362
# PLN      -0.049349  -0.072817
# QAR       0.061487   0.092792
# RON      -0.032782  -0.053757
# SAR       0.060378   0.091392
# THB       0.032502  -0.003842
# TRY      -0.314049  -0.397967
# TWD       0.004532   0.030723
# UAH      -0.077550   0.002777
# VND       0.051450   0.097020

# %%
df.to_csv("abscur_last.csv")

# %% [markdown]
# # Предача последних абсолютных курсов

# %%
_ = lib_abscur_post.sendTable(df,"last_abs")

# %% [markdown]
# # Публикация через центральный сервис в каналах

# %%
import lib_abscur_post

# if close_abs.index[-1] != prevPostDate:
#     title = "Абсолютные курсы на " + close_abs.index[-1]
#     message = ', '.join(['1 ' + str(cur) + " = " + str(np.round(price,4)) + " (" + str(np.round(pct*100,2)) + "%) ABS" for cur,price,pct in df.iloc[:,:2].reset_index().values])
#     link = 'https://docs.google.com/spreadsheets/d/1CrNvvV-p6XG7lSJXftPKk_aY4nuH4WK25rPxaNKrM3U'
#     _ = lib_abscur_post.postToChanels(title,message,link)
