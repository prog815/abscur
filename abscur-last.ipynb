# %% [markdown]
# # Ипорт библиотек

# %%
import numpy as np
import pandas as pd

import lib_abscur_post

# %%
import os

def find(name, path):
    for root, dirs, files in os.walk(path):
        if name in files:
            return os.path.join(root, name)

# %% [markdown]
# # Предыдущая выгрузка последних

# %%
prevPostDate = 'давно'
try:
    prevPostDate = str(pd.read_csv(find('abscur_last.csv','..'),index_col=0).columns[0][-10:])
except:
    pass
prevPostDate
# Out:
# '2022-01-16'

# %% [markdown]
# # История абсолютных курсов

# %%
close_abs = pd.read_pickle(find('close_abs.pkl','..'))
close_abs
# Out:
#                   AUD        CAD       HKD       JPY       SEK        USD  \
# Date
# 2017-01-17  12.619701  12.817297  2.177670  0.147909  1.887705  16.887196
# 2017-01-18  12.676237  12.852765  2.164736  0.148693  1.887581  16.787889
# 2017-01-19  12.672488  12.725494  2.176326  0.147050  1.886437  16.880665
# 2017-01-20  12.754587  12.654320  2.173368  0.146601  1.883851  16.858437
# 2017-01-23  12.705995  12.612716  2.162931  0.147401  1.890764  16.779905
# ...               ...        ...       ...       ...       ...        ...
# 2022-01-12  13.513914  14.902598  2.404237  0.162478  2.075076  18.747160
# 2022-01-13  13.587282  14.922848  2.394527  0.162679  2.087390  18.657815
# 2022-01-14  13.600379  14.934449  2.398466  0.163673  2.092200  18.677397
# 2022-01-15  13.600560  14.934647  2.398498  0.163675  2.092228  18.677645
# 2022-01-16  13.605629  14.940214  2.399392  0.163736  2.093008  18.684144
#
#                   CHF        EUR       CNY       CZK  ...       PKR       PLN  \
# Date                                                  ...
# 2017-01-17  16.699117  17.901000  2.450095  0.662813  ...  0.163636  4.094700
# 2017-01-18  16.737478  17.952914  2.451798  0.664896  ...  0.162516  4.118858
# 2017-01-19  16.746267  17.931747  2.469313  0.664050  ...  0.161229  4.114666
# 2017-01-20  16.749388  17.962058  2.456725  0.665123  ...  0.160940  4.111002
# 2017-01-23  16.762367  17.971516  2.442620  0.665472  ...  0.163403  4.113529
# ...               ...        ...       ...       ...  ...       ...       ...
# 2022-01-12  20.294456  21.297623  2.942473  0.875545  ...  0.106397  4.697359
# 2022-01-13  20.409058  21.337774  2.935976  0.880448  ...  0.106071  4.721490
# 2022-01-14  20.500648  21.396851  2.939280  0.873106  ...  0.106122  4.717944
# 2022-01-15  20.500920  21.397135  2.939319  0.873117  ...  0.106123  4.718007
# 2022-01-16  20.508562  21.405681  2.941736  0.873443  ...  0.105973  4.719648
#
#                  QAR       RON       SAR       THB       TRY       TWD  \
# Date
# 2017-01-17  4.640360  3.981796  4.507941  0.476770  4.436958  0.533039
# 2017-01-18  4.613198  3.993408  4.482269  0.475982  4.463914  0.535482
# 2017-01-19  4.638692  3.991739  4.506438  0.476586  4.434613  0.534554
# 2017-01-20  4.632584  4.000199  4.500504  0.476093  4.405131  0.533275
# 2017-01-23  4.609358  3.989232  4.474522  0.474948  4.456305  0.532307
# ...              ...       ...       ...       ...       ...       ...
# 2022-01-12  5.151026  4.314353  5.000445  0.562944  1.362389  0.678581
# 2017-01-18  8.89710  1.41819  35.270000   3.76080  31.351000  27.316999
# 2017-01-19  8.95171  1.42928  35.419998   3.80657  31.579000  27.405001
# 2017-01-20  8.95083  1.42520  35.410000   3.82700  31.613001  27.150999
# 2017-01-23  8.87610  1.42049  35.330002   3.76543  31.523001  26.957001
# ...             ...      ...        ...       ...        ...        ...
# 2022-01-12  9.03542  1.35064  33.301998  13.76050  27.627001  27.264631
# 2022-01-13  8.93325  1.34590  33.250999  13.24340  27.598600  27.460918
# 2022-01-14  8.92318  1.34605  33.200001  13.58270  27.566000  27.495604
# 2022-01-15  8.92318  1.34605  33.200001  13.58270  27.566000  27.495604
# 2022-01-16  8.92318  1.34605  33.200001  13.58270  27.566000  27.719999
#
#              USDVND    USDZAR
# Date
# 2017-01-17  22195.0  13.66298
# 2017-01-18  22309.0  13.45436
# 2017-01-19  22196.0  13.61750
# 2017-01-20  22084.0  13.54200
# 2017-01-23  22100.0  13.60689
# ...             ...       ...
# 2022-01-12  22698.0  15.48848
# 2022-01-13  22698.0  15.27967
# 2022-01-14  22710.0  15.39460
# 2022-01-15  22710.0  15.39460
# 2022-01-16  22708.0  15.39460
#
# [1306 rows x 87 columns]

# %%
_ = lib_abscur_post.sendTable(close_par,"par_hist")

# %% [markdown]
# # Последние парные курсы

# %%
d = pd.DataFrame(index=pd.date_range(close_par.index[0],close_par.index[-1]),columns=close_par.columns)
d.loc[close_par.index.values] = close_par.values
d.fillna(method='pad',inplace=True)

df = pd.DataFrame()
df[f'курс на {close_par.index[-1]}'] = d.iloc[-1,:]
df['% изм.день'] = d.pct_change(1).iloc[-1,:]
df['% изм.неделя'] = d.pct_change(7).iloc[-1,:]
df['% изм.месяц'] = d.pct_change(30).iloc[-1,:]
df['% изм.квартал'] = d.pct_change(90).iloc[-1,:]
df['% изм.полгода'] = d.pct_change(180).iloc[-1,:]
df['% изм.год'] = d.pct_change(365).iloc[-1,:]
df
# Out:
#         курс на 2022-01-16  % изм.день  % изм.неделя  % изм.месяц  \
# AUDCAD            0.910360    0.000000     -0.001481    -0.006916
# AUDHKD            5.670230    0.000000      0.014902     0.012722
# AUDJPY           83.091003    0.000000      0.001253     0.018871
# AUDSEK            6.502400    0.000000     -0.007267     0.003240
# AUDUSD            0.728226    0.000000      0.016706     0.014863
# ...                    ...         ...           ...          ...
# USDTRY           13.582700    0.000000     -0.014468    -0.132692
# USDTWD           27.566000    0.000000     -0.001955    -0.006906
# USDUAH           27.719999    0.008161      0.017972     0.029393
# USDVND        22708.000000   -0.000088     -0.001627    -0.012266
# USDZAR           15.394600    0.000000     -0.019284    -0.033276
#
#         % изм.квартал  % изм.полгода  % изм.год
# AUDCAD      -0.008992      -0.026353  -0.073896
# AUDHKD      -0.018048      -0.005707  -0.059402
# AUDJPY      -0.021065       0.033599   0.029628
# AUDSEK       0.017622       0.019184   0.006076
# AUDUSD      -0.019196      -0.007759  -0.063472
# ...               ...            ...        ...
# USDTRY       0.470475       0.583047   0.843947
# USDTWD      -0.015500      -0.018210  -0.015039
# USDUAH       0.060828       0.029222  -0.003856
# USDVND      -0.002197      -0.013553  -0.015435
# USDZAR       0.055929       0.059455   0.020666
#
# [87 rows x 7 columns]

# %%
df.to_csv("par_last.csv")

# %%
_ = lib_abscur_post.sendTable(df,"last_par")

# %% [markdown]
# # Последние абсолютные курсы

# %%
d = pd.DataFrame(index=pd.date_range(close_abs.index[0],close_abs.index[-1]),columns=close_abs.columns)
d.loc[close_abs.index.values] = close_abs.values
d.fillna(method='pad',inplace=True)

df = pd.DataFrame()
df[f'курс на {close_abs.index[-1]}'] = close_abs.iloc[-1,:]
df['% изм.день'] = d.pct_change(1).iloc[-1,:]
df['% изм.неделя'] = d.pct_change(7).iloc[-1,:]
df['% изм.месяц'] = d.pct_change(30).iloc[-1,:]
df['% изм.квартал'] = d.pct_change(90).iloc[-1,:]
df['% изм.полгода'] = d.pct_change(180).iloc[-1,:]
df['% изм.год'] = d.pct_change(365).iloc[-1,:]
df
# Out:
#      курс на 2022-01-16  % изм.день  % изм.неделя  % изм.месяц  % изм.квартал  \
# AUD           13.605629    0.000373      0.006976     0.001841      -0.001687
# CAD           14.940214    0.000373      0.008214     0.008768       0.007089
# HKD            2.399392    0.000373     -0.007793    -0.010713       0.016709
# JPY            0.163736    0.000373      0.005908    -0.016481       0.019822
# SEK            2.093008    0.000373      0.014376    -0.001503      -0.018730
# USD           18.684144    0.000348     -0.009655    -0.012878       0.017951
# CHF           20.508562    0.000373      0.001818    -0.004179       0.031869
# EUR           21.405681    0.000399      0.004839    -0.001807       0.005695
# CNY            2.941736    0.000822     -0.005254    -0.010981       0.031080
# CZK            0.873443    0.000374      0.001596     0.031134       0.039841
# GBP           25.621250    0.000371      0.003668     0.016124       0.014365
# ILS            6.007228    0.000374     -0.008662    -0.018800       0.053944
# NOK            2.146402    0.000373      0.011235     0.019234      -0.014244
# NZD           12.819913    0.000373      0.008243    -0.003370      -0.014091
# RUB            0.244835    0.000373     -0.008822    -0.046242      -0.052379
# SGD           13.880712    0.000373      0.001523    -0.000035       0.019532
# ZAR            1.214292    0.000374      0.010552     0.021161      -0.035491
# AED            5.087028    0.000130     -0.009871    -0.013093       0.017876
# ARS            0.180073    0.000348     -0.014666    -0.030936      -0.026989
# BRL            3.380705    0.000348      0.018245     0.015824       0.005371
# CLP            0.022897    0.000348      0.015953     0.023425       0.026995
# COP            0.004712    0.000348      0.006721    -0.000008      -0.034272
# DKK            2.876546    0.000348      0.004137    -0.002945       0.005470
# EGP            1.194638    0.002291     -0.006705    -0.008593       0.021583
# HUF            0.060394    0.000348      0.020650     0.035643       0.019438
# IDR            0.001306   -0.001680     -0.002525    -0.007703       0.001015
# INR            0.251974   -0.002063     -0.006072     0.013966       0.029687
# ISK            0.145765    0.000348     -0.000847    -0.008797       0.020810
# KRW            0.015746    0.000348      0.006344    -0.013261       0.013816
# KWD           61.950077    0.000348     -0.007784    -0.009180       0.016837
# KZT            0.042929   -0.005925     -0.015119    -0.013505      -0.009096
# MXN            0.918877    0.000348     -0.001890     0.010702       0.018618
# MYR            4.475244    0.000348     -0.001116    -0.006022       0.013196
# PEN            4.828318    0.004820      0.014734     0.028268       0.034076
# PHP            0.364142   -0.000919     -0.004637    -0.038273       0.005928
# PKR            0.105973   -0.001411     -0.007746    -0.005376      -0.013284
# PLN            4.719648    0.000348      0.008304     0.018280       0.011394
# QAR            5.133006    0.000348     -0.009655    -0.013014       0.017951
# RON            4.335370    0.000348      0.004408    -0.000968       0.006448
# SAR            4.979252   -0.000564     -0.010321    -0.013281       0.017408
# THB            0.562775    0.000348      0.000875    -0.006932       0.025003
# TRY            1.375584    0.000348      0.004883     0.138144      -0.307740
# TWD            0.677797    0.000348     -0.007715    -0.006014       0.033978
# UAH            0.674031   -0.007750     -0.027139    -0.041065      -0.040419
# VND            0.000823    0.000436     -0.008042    -0.000620       0.020192
#
#      % изм.полгода  % изм.год
# AUD       0.014725  -0.014582
# CAD       0.042382   0.064050
# HKD       0.020607   0.047591
# JPY      -0.018102  -0.042557
# SEK      -0.004510  -0.020716
# USD       0.022869   0.052187
# CHF       0.031471   0.025987
# EUR      -0.006306  -0.007840
# CNY       0.044709   0.071977
# CZK       0.041201   0.057390
# GBP       0.026103   0.054560
# ILS       0.084551   0.076769
# NOK       0.051900   0.023197
# NZD       0.012103   0.000353
# RUB       0.000842   0.011139
# SGD       0.036400   0.035231
# ZAR      -0.034100   0.031751
# AED       0.022674   0.051987
# ARS      -0.050616  -0.131527
# BRL      -0.028175  -0.010810
# CLP      -0.047641  -0.063863
# COP      -0.027896  -0.085968
# DKK      -0.006743  -0.008300
# EGP       0.022889   0.052104
# HUF       0.008510   0.005447
# IDR       0.048575   0.034398
# INR       0.034489   0.037098
# ISK      -0.012402   0.055389
# KRW      -0.008629  -0.029134
# KWD       0.018121   0.055850
# KZT      -0.000922   0.009115
# MXN       0.008001   0.020606
# MYR       0.034384   0.017156
# PEN       0.010410  -0.018834
# PHP       0.018423  -0.015587
# PKR      -0.076309  -0.046640
# PLN       0.006281  -0.007721
# QAR       0.022728   0.052187
# RON      -0.009671  -0.022106
# SAR       0.021227   0.051005
# THB       0.011778  -0.049862
# TRY      -0.353861  -0.429383
# TWD       0.041841   0.068253
# UAH      -0.006173   0.056260
# VND       0.036923   0.068683

# %%
df.to_csv("abscur_last.csv")

# %% [markdown]
# # Предача последних абсолютных курсов

# %%
_ = lib_abscur_post.sendTable(df,"last_abs")

# %% [markdown]
# # Публикация через центральный сервис в каналах

# %%
import lib_abscur_post

if close_abs.index[-1] != prevPostDate:
    title = "Абсолютные курсы на " + close_abs.index[-1]
    message = ', '.join(['1 ' + str(cur) + " = " + str(np.round(price,4)) + " (" + str(np.round(pct*100,2)) + "%) ABS" for cur,price,pct in df.iloc[:,:2].reset_index().values])
    link = 'https://docs.google.com/spreadsheets/d/1CrNvvV-p6XG7lSJXftPKk_aY4nuH4WK25rPxaNKrM3U'
    _ = lib_abscur_post.postToChanels(title,message,link)
