# %% [markdown]
# <a href="https://www.kaggle.com/code/eavprog/abscur-posled-kurs?scriptVersionId=115232477" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Последние абсолютные курсы для проекта "Абсолютный валютные курсы"
#
# [**Оглавление проекта "Абсолютные валютные курсы"**](https://docs.google.com/spreadsheets/d/1UgC2NfKtKJPaXglsmVJET7Xnp2ZtOzJgKD9DN-VGFA8/edit#gid=77497797)
#
# Данные для настоящего расчета берутся из тетрадки [**Источник данных для проекта "Абсолютные валютные курсы"**](https://www.kaggle.com/code/eavprog/abscur-data).
#
# В настоящем расчете показываем абсолютные курсы на последнюю имеющуюся дату. Показываем расшифровку тикера валюты и ссылку на страницу с описанием на Wikipedia. Курсы обновляются ежедневно.

# %%
import abscur_menu
abscur_menu.print_menu()
# Out:
# [Источник данных с абсолютными курсами](https://www.kaggle.com/code/eavprog/abscur-data)
# [Последние абсолютные курсы](https://www.kaggle.com/code/eavprog/abscur-posled-kurs)
# [Абсолютные курсы голубых фишек Московской биржи](https://www.kaggle.com/code/eavprog/mmvb-abscur-blue-fishki)

# %%
import pandas as pd
import datetime

abscur = pd.read_csv('/kaggle/input/abscur-data/abscur.csv',index_col=0,parse_dates=True)
last_abscur = abscur.last("1D").transpose()

last_abscur = last_abscur.sort_index()

last_abscur.columns = ["курс на " + datetime.datetime.strftime(last_abscur.columns[0],"%Y-%m-%d")]

abscur_ras = pd.read_csv('/kaggle/input/abscur-data/cur_ras.csv',index_col=0)

def make_clickable(val):
        return '<a target="_blank" href="{}">Wikipedia link</a>'.format(val)


    
last_abscur.merge(abscur_ras,left_index=True,right_index=True).style.format({'Ссылка на Wikipedia': make_clickable})
# Out:
# <style type="text/css">
# </style>
# <table id="T_c793c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >курс на 2022-12-30</th>
#       <th class="col_heading level0 col1" >Расшифровка</th>
#       <th class="col_heading level0 col2" >Ссылка на Wikipedia</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c793c_level0_row0" class="row_heading level0 row0" >AED</th>
#       <td id="T_c793c_row0_col0" class="data row0 col0" >5.596900</td>
#       <td id="T_c793c_row0_col1" class="data row0 col1" >Дирхам ОАЭ</td>
#       <td id="T_c793c_row0_col2" class="data row0 col2" ><a target="_blank" href="https://ru.wikipedia.org/wiki/%D0%94%D0%B8%D1%80%D1%85%D0%B0%D0%BC_%D0%9E%D0%90%D0%AD">Wikipedia link</a></td>
#     </tr>
#     <tr>
#       <th id="T_c793c_level0_row1" class="row_heading level0 row1" >ARS</th>
#       <td id="T_c793c_row1_col0" class="data row1 col0" >0.116300</td>
#       <td id="T_c793c_row1_col1" class="data row1 col1" >Аргентинское песо</td>
#       <td id="T_c793c_row1_col2" class="data row1 col2" ><a target="_blank" href="https://ru.wikipedia.org/wiki/%D0%90%D1%80%D0%B3%D0%B5%D0%BD%D1%82%D0%B8%D0%BD%D1%81%D0%BA%D0%BE%D0%B5_%D0%BF%D0%B5%D1%81%D0%BE">Wikipedia link</a></td>
#     </tr>
#     <tr>
#       <th id="T_c793c_level0_row2" class="row_heading level0 row2" >AUD</th>
#       <td id="T_c793c_row2_col0" class="data row2 col0" >14.023200</td>
#       <td id="T_c793c_row2_col1" class="data row2 col1" >Австралийский доллар</td>
#       <td id="T_c793c_row2_col2" class="data row2 col2" ><a target="_blank" href="https://ru.wikipedia.org/wiki/%D0%90%D0%B2%D1%81%D1%82%D1%80%D0%B0%D0%BB%D0%B8%D0%B9%D1%81%D0%BA%D0%B8%D0%B9_%D0%B4%D0%BE%D0%BB%D0%BB%D0%B0%D1%80">Wikipedia link</a></td>
#     </tr>
#     <tr>
#       <th id="T_c793c_level0_row3" class="row_heading level0 row3" >BRL</th>
#       <td id="T_c793c_row3_col0" class="data row3 col0" >3.882100</td>
#       <td id="T_c793c_row3_col1" class="data row3 col1" >Бразильский реал</td>
#       <td id="T_c793c_row3_col2" class="data row3 col2" ><a target="_blank" href="https://ru.wikipedia.org/wiki/%D0%91%D1%80%D0%B0%D0%B7%D0%B8%D0%BB%D1%8C%D1%81%D0%BA%D0%B8%D0%B9_%D1%80%D0%B5%D0%B0%D0%BB">Wikipedia link</a></td>
#     </tr>
#     <tr>
#       <th id="T_c793c_level0_row4" class="row_heading level0 row4" >CAD</th>
#       <td id="T_c793c_row4_col0" class="data row4 col0" >15.173000</td>
#       <td id="T_c793c_row4_col1" class="data row4 col1" >Канадский доллар</td>
#       <td id="T_c793c_row4_col2" class="data row4 col2" ><a target="_blank" href="https://ru.wikipedia.org/wiki/%D0%9A%D0%B0%D0%BD%D0%B0%D0%B4%D1%81%D0%BA%D0%B8%D0%B9_%D0%B4%D0%BE%D0%BB%D0%BB%D0%B0%D1%80">Wikipedia link</a></td>
#     </tr>
#     <tr>
#       <th id="T_c793c_level0_row5" class="row_heading level0 row5" >CHF</th>
#       <td id="T_c793c_row5_col0" class="data row5 col0" >22.242900</td>
#       <td id="T_c793c_row5_col1" class="data row5 col1" >Швейцарский франк</td>
#       <td id="T_c793c_row5_col2" class="data row5 col2" ><a target="_blank" href="https://ru.wikipedia.org/wiki/%D0%A8%D0%B2%D0%B5%D0%B9%D1%86%D0%B0%D1%80%D1%81%D0%BA%D0%B8%D0%B9_%D1%84%D1%80%D0%B0%D0%BD%D0%BA">Wikipedia link</a></td>
#     </tr>
#     <tr>
#       <th id="T_c793c_level0_row6" class="row_heading level0 row6" >CLP</th>
#       <td id="T_c793c_row6_col0" class="data row6 col0" >0.024300</td>
#       <td id="T_c793c_row6_col1" class="data row6 col1" >Чилийское песо</td>
#       <td id="T_c793c_row6_col2" class="data row6 col2" ><a target="_blank" href="https://ru.wikipedia.org/wiki/%D0%A7%D0%B8%D0%BB%D0%B8%D0%B9%D1%81%D0%BA%D0%BE%D0%B5_%D0%BF%D0%B5%D1%81%D0%BE">Wikipedia link</a></td>
#     </tr>
#     <tr>
#       <th id="T_c793c_level0_row7" class="row_heading level0 row7" >CNY</th>
#       <td id="T_c793c_row7_col0" class="data row7 col0" >2.981100</td>
#       <td id="T_c793c_row7_col1" class="data row7 col1" >Китайский юань</td>
#       <td id="T_c793c_row7_col2" class="data row7 col2" ><a target="_blank" href="https://ru.wikipedia.org/wiki/%D0%9A%D0%B8%D1%82%D0%B0%D0%B9%D1%81%D0%BA%D0%B8%D0%B9_%D1%8E%D0%B0%D0%BD%D1%8C">Wikipedia link</a></td>
#     </tr>
#     <tr>
#       <th id="T_c793c_level0_row8" class="row_heading level0 row8" >COP</th>
#       <td id="T_c793c_row8_col0" class="data row8 col0" >0.004200</td>
#       <td id="T_c793c_row8_col1" class="data row8 col1" >Колумбийское песо</td>
#       <td id="T_c793c_row8_col2" class="data row8 col2" ><a target="_blank" href="https://ru.wikipedia.org/wiki/%D0%9A%D0%BE%D0%BB%D1%83%D0%BC%D0%B1%D0%B8%D0%B9%D1%81%D0%BA%D0%BE%D0%B5_%D0%BF%D0%B5%D1%81%D0%BE">Wikipedia link</a></td>
#     </tr>
#     <tr>
#       <th id="T_c793c_level0_row9" class="row_heading level0 row9" >CZK</th>
#       <td id="T_c793c_row9_col0" class="data row9 col0" >0.911800</td>
#       <td id="T_c793c_row9_col1" class="data row9 col1" >Чешская крона</td>
#       <td id="T_c793c_row9_col2" class="data row9 col2" ><a target="_blank" href="https://ru.wikipedia.org/wiki/%D0%A7%D0%B5%D1%88%D1%81%D0%BA%D0%B0%D1%8F_%D0%BA%D1%80%D0%BE%D0%BD%D0%B0">Wikipedia link</a></td>
#     </tr>
#     <tr>
#       <th id="T_c793c_level0_row10" class="row_heading level0 row10" >DKK</th>
#       <td id="T_c793c_row10_col0" class="data row10 col0" >2.957600</td>
#       <td id="T_c793c_row10_col1" class="data row10 col1" >Датская крона</td>
#       <td id="T_c793c_row10_col2" class="data row10 col2" ><a target="_blank" href="https://ru.wikipedia.org/wiki/%D0%94%D0%B0%D1%82%D1%81%D0%BA%D0%B0%D1%8F_%D0%BA%D1%80%D0%BE%D0%BD%D0%B0">Wikipedia link</a></td>
#     </tr>
#     <tr>
#       <th id="T_c793c_level0_row11" class="row_heading level0 row11" >EGP</th>
#       <td id="T_c793c_row11_col0" class="data row11 col0" >0.832500</td>
#       <td id="T_c793c_row11_col1" class="data row11 col1" >Египетский фунт</td>
#       <td id="T_c793c_row11_col2" class="data row11 col2" ><a target="_blank" href="https://ru.wikipedia.org/wiki/%D0%95%D0%B3%D0%B8%D0%BF%D0%B5%D1%82%D1%81%D0%BA%D0%B8%D0%B9_%D1%84%D1%83%D0%BD%D1%82">Wikipedia link</a></td>
#     </tr>
#     <tr>
#       <th id="T_c793c_level0_row12" class="row_heading level0 row12" >EUR</th>
#       <td id="T_c793c_row12_col0" class="data row12 col0" >22.016500</td>
#       <td id="T_c793c_row12_col1" class="data row12 col1" >Евро</td>
#       <td id="T_c793c_row12_col2" class="data row12 col2" ><a target="_blank" href="https://ru.wikipedia.org/wiki/%D0%95%D0%B2%D1%80%D0%BE">Wikipedia link</a></td>
#     </tr>
#     <tr>
#       <th id="T_c793c_level0_row13" class="row_heading level0 row13" >GBP</th>
#       <td id="T_c793c_row13_col0" class="data row13 col0" >24.882500</td>
#       <td id="T_c793c_row13_col1" class="data row13 col1" >Фунт стерлингов</td>
#       <td id="T_c793c_row13_col2" class="data row13 col2" ><a target="_blank" href="https://ru.wikipedia.org/wiki/%D0%A4%D1%83%D0%BD%D1%82_%D1%81%D1%82%D0%B5%D1%80%D0%BB%D0%B8%D0%BD%D0%B3%D0%BE%D0%B2">Wikipedia link</a></td>
#     </tr>
#     <tr>
#       <th id="T_c793c_level0_row14" class="row_heading level0 row14" >HKD</th>
#       <td id="T_c793c_row14_col0" class="data row14 col0" >2.635300</td>
#       <td id="T_c793c_row14_col1" class="data row14 col1" >Гонконгский доллар</td>
#       <td id="T_c793c_row14_col2" class="data row14 col2" ><a target="_blank" href="https://ru.wikipedia.org/wiki/%D0%93%D0%BE%D0%BD%D0%BA%D0%BE%D0%BD%D0%B3%D1%81%D0%BA%D0%B8%D0%B9_%D0%B4%D0%BE%D0%BB%D0%BB%D0%B0%D1%80">Wikipedia link</a></td>
#     </tr>
#     <tr>
#       <th id="T_c793c_level0_row15" class="row_heading level0 row15" >HUF</th>
#       <td id="T_c793c_row15_col0" class="data row15 col0" >0.055100</td>
#       <td id="T_c793c_row15_col1" class="data row15 col1" >Венгерский форинт</td>
#       <td id="T_c793c_row15_col2" class="data row15 col2" ><a target="_blank" href="https://ru.wikipedia.org/wiki/%D0%A4%D0%BE%D1%80%D0%B8%D0%BD%D1%82">Wikipedia link</a></td>
#     </tr>
#     <tr>
#       <th id="T_c793c_level0_row16" class="row_heading level0 row16" >IDR</th>
#       <td id="T_c793c_row16_col0" class="data row16 col0" >0.001300</td>
#       <td id="T_c793c_row16_col1" clas
