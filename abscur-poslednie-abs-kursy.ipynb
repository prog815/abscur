# %% [markdown]
# <a href="https://www.kaggle.com/code/eavprog/abscur-poslednie-abs-kursy?scriptVersionId=114056289" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd

# %%
data_abs = pd.read_csv('/kaggle/input/abscur-data/abscur.csv',index_col=0,parse_dates=True)
data_abs
# Out:
#                 AUD     HKD     JPY     SEK      USD      CAD      CHF  \
# Date
# 2022-05-27  13.9259  2.4785  0.1528  1.9844  19.4366  15.2797  20.3149
# 2022-05-30  13.9348  2.4679  0.1517  1.9875  19.3578  15.2964  20.2277
# 2022-05-31  13.9177  2.4731  0.1507  1.9891  19.3854  15.3296  20.2144
# 2022-06-01  13.9625  2.4809  0.1495  1.9788  19.4540  15.3716  20.2046
# 2022-06-02  14.0753  2.4707  0.1491  1.9999  19.3754  15.4075  20.2313
# ...             ...     ...     ...     ...      ...      ...      ...
# 2022-12-12  13.9151  2.6538  0.1498  1.9975  20.6281  15.1276  22.0352
# 2022-12-13  14.0509  2.6380  0.1511  2.0093  20.4995  15.1326  22.0758
# 2022-12-14  14.0538  2.6352  0.1511  2.0166  20.4832  15.1149  22.1495
# 2022-12-15  13.8205  2.6527  0.1496  1.9950  20.6036  15.0961  22.2069
# 2022-12-16  13.8470  2.6491  0.1499  2.0011  20.5793  15.1053  22.2174
#
#                 EUR     CNY     CZK  ...     PKR     PLN     QAR     RON  \
# ...

# %%
data_abs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 146 entries, 2022-05-27 to 2022-12-16
# Data columns (total 45 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AUD     146 non-null    float64
#  1   HKD     146 non-null    float64
#  2   JPY     146 non-null    float64
#  3   SEK     146 non-null    float64
#  4   USD     146 non-null    float64
#  5   CAD     146 non-null    float64
#  6   CHF     146 non-null    float64
#  7   EUR     146 non-null    float64
#  8   CNY     146 non-null    float64
#  9   CZK     146 non-null    float64
#  10  GBP     146 non-null    float64
#  11  ILS     146 non-null    float64
#  12  NOK     146 non-null    float64
#  13  NZD     146 non-null    float64
#  14  RUB     146 non-null    float64
#  15  SGD     146 non-null    float64
#  16  ZAR     146 non-null    float64
#  17  AED     146 non-null    float64
#  18  ARS     146 non-null    float64
#  19  BRL     146 non-null    float64
# ...
