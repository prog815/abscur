# %% [markdown]
# <a href="https://www.kaggle.com/code/eavprog/abscur-stoimost-absa?scriptVersionId=133669747" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Стоимость Абса
#
# В настоящем проекте принято выражать валюты, акции и другие инструменты по абсолютному курсу, т.е. в Абсах. А сколько стоит один Абс через другие валюты? Для вычисления возьмем и обратим дробь с абсолютным валютным курсом (см. https://www.kaggle.com/eavprog/abscur-posled-kurs).
#
# Например, если мы хотим узнать стоимость одного Абса в долларах, то возьмем курс доллара к Абсу и обратим его: 1 / курс доллара к Абсу. Таким образом, если курс доллара к Абсу равен 20.72, то стоимость одного Абса в долларах будет 0.048 доллара.
#
# Аналогично можно вычислить стоимость Абса в других валютах или инструментах. Например, для вычисления стоимости Абса в евро нужно взять обратный курс евро к Абсу.
#
# Важно учитывать, что курсы валют постоянно меняются и могут быть различными на разных биржах и площадках. При вычислениях стоимости Абса следует использовать актуальные данные о курсах валют и других инструментов.

# %%
import numpy as np
import pandas as pd
import datetime
import abscur_menu
import abscur_post as ap
from IPython.display import Markdown, display

# меню проекта печатаем
abscur_menu.print_menu()

# загрузка истории абсолютных курсов
abscur = pd.read_csv("/kaggle/input/abscur-data/abscur.csv",index_col=0,parse_dates=['Date'])

# загрузка расшифровки валют
ras_cur = pd.read_csv("/kaggle/input/abscur-data/cur_ras.csv",index_col=0)
# Out:
# # Оглавление проекта "Абсолютный валютный курс"
#
# ![Проект "Абсолютный валютный курс"](https://i.ibb.co/cL0D27B/abscur-znak.jpg)
#
# ## Представительства проекта:
# [**БЛОГ**](http://www.abscur.ru) -
# [**VK**](https://vk.com/abscur) -
# [**WhatsApp**](https://chat.whatsapp.com/KrNJXAKizPxDlDSjYfdpQs) -
# [**Viber**](https://invite.viber.com/?g2=AQB63y7Cm%2BNJK0tNZW%2F9kI00M6Wr8HuZ7XeamzN4jZCve8Aq9%2FiD3DY56Eqcf7dc) -
# [**Telegram**](https://t.me/AbsCur) -
# [**ОК**](https://ok.ru/group/53547043520717) -
# [**GitHub**](https://github.com/prog815/abscur) -
# [**YouTube**](https://www.youtube.com/@eavprog8/community) -
# [**Smart-Lab**](https://smart-lab.ru/my/eavpred/) -
# [**VC.ru**](https://vc.ru/s/1826351-absolyutnyy-kurs-valyut) -
# [**Kaggle**](https://www.kaggle.com/code/eavprog/abscur-about)
#
# ## Абсолютные валютные курсы:
# - [О проекте](https://www.kaggle.com/eavprog/abscur-about)
# - [Источник данных с абсолютными курсами](https://www.kaggle.com/code/eavprog/abscur-data)
# - [Последние абсолютные курсы](https://www.kaggle.com/code/eavprog/abscur-posled-kurs)
# - [Графики истории абсолютных валютных курсов](https://www.kaggle.com/eavprog/abscur-hist)
# - [Стоимость Абса](https://www.kaggle.com/eavprog/abscur-stoimost-absa)
# - [Связь валют на графах через корреляцию](https://www.kaggle.com/code/eavprog/abscur-svyas-valut)
# - [Рейтинг абсолютной доходности](https://www.kaggle.com/eavprog/abscur-reyting-dohod)
# - [Рейтинг валют по абсолютным курсам и коэффициенту Шарпа](https://www.kaggle.com/eavprog/abscur-sharp)
# - [Рейтинг абсолютной стабильности валют](https://www.kaggle.com/eavprog/abscur-reit-stabil)
#
# ## Парные валютные курсы
# - [Графики истории парных валютных курсов](https://www.kaggle.com/eavprog/abscur-par-hist)
#
# ## Голубые фишки Московской биржи
# - [Абсолютные курсы голубых фишек Московской биржи](https://www.kaggle.com/code/eavprog/mmvb-abscur-blue-fishki)
# - [Рейтинг голубых фишек Московской биржи по абсолютным курсам и коэффициенту Шарпа](https://www.kaggle.com/code/eavprog/abscur-bluefish-sharp)
# - [Рейтинг голубых фишек Московской биржи по рублевым курсам и коэффициенту Шарпа](https://www.kaggle.com/eavprog/abscur-bluefish-sharp-rub)
#
# ## Товары Московской биржи
# - [Абсолютные курсы товаров Мосбиржи](https://www.kaggle.com/eavprog/mmvb-abscur-tovar)
# - [Рейтинг товаров Московской биржи по коэффициенту Шарпа (долларовый и абсолютный)](https://www.kaggle.com/eavprog/abscur-tovar-sharp)
#
# ---

# %%
names = list(abscur.columns)
names.sort()
text = "# Стоимость Абса на " + datetime.datetime.strftime(abscur.index[-1],"%Y-%m-%d") + "\n\n"
text_post = "Стоимость Абса на " + datetime.datetime.strftime(abscur.index[-1],"%Y-%m-%d") + "\n---\n"
for name in names:
    text += "- 1 **Абс** = " + str(np.round(1/abscur[name][-1],3)) + " **" + name + "** ([**" + ras_cur.loc[name][0] + "**](" + ras_cur.loc[name][1]+ "))" + " (см. [график истории абсолютного курса " + name + "](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#" + name + "))\n"
    text_post += "1 Абс = " + str(np.round(1/abscur[name][-1],3)) + " " + name + " (" + ras_cur.loc[name][0] + ")" + "\n"
display(Markdown(text))
text_post += "---\nИсточник - https://www.kaggle.com/code/eavprog/abscur-stoimost-absa"
ap.send_text(text_post)
# Out:
# # Стоимость Абса на 2023-06-14
#
# - 1 **Абс** = 0.176 **AED** ([**Дирхам ОАЭ**](https://ru.wikipedia.org/wiki/%D0%94%D0%B8%D1%80%D1%85%D0%B0%D0%BC_%D0%9E%D0%90%D0%AD)) (см. [график истории абсолютного курса AED](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#AED))
# - 1 **Абс** = 11.819 **ARS** ([**Аргентинское песо**](https://ru.wikipedia.org/wiki/%D0%90%D1%80%D0%B3%D0%B5%D0%BD%D1%82%D0%B8%D0%BD%D1%81%D0%BA%D0%BE%D0%B5_%D0%BF%D0%B5%D1%81%D0%BE)) (см. [график истории абсолютного курса ARS](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#ARS))
# - 1 **Абс** = 0.071 **AUD** ([**Австралийский доллар**](https://ru.wikipedia.org/wiki/%D0%90%D0%B2%D1%81%D1%82%D1%80%D0%B0%D0%BB%D0%B8%D0%B9%D1%81%D0%BA%D0%B8%D0%B9_%D0%B4%D0%BE%D0%BB%D0%BB%D0%B0%D1%80)) (см. [график истории абсолютного курса AUD](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#AUD))
# - 1 **Абс** = 0.233 **BRL** ([**Бразильский реал**](https://ru.wikipedia.org/wiki/%D0%91%D1%80%D0%B0%D0%B7%D0%B8%D0%BB%D1%8C%D1%81%D0%BA%D0%B8%D0%B9_%D1%80%D0%B5%D0%B0%D0%BB)) (см. [график истории абсолютного курса BRL](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#BRL))
# - 1 **Абс** = 0.064 **CAD** ([**Канадский доллар**](https://ru.wikipedia.org/wiki/%D0%9A%D0%B0%D0%BD%D0%B0%D0%B4%D1%81%D0%BA%D0%B8%D0%B9_%D0%B4%D0%BE%D0%BB%D0%BB%D0%B0%D1%80)) (см. [график истории абсолютного курса CAD](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#CAD))
# - 1 **Абс** = 0.043 **CHF** ([**Швейцарский франк**](https://ru.wikipedia.org/wiki/%D0%A8%D0%B2%D0%B5%D0%B9%D1%86%D0%B0%D1%80%D1%81%D0%BA%D0%B8%D0%B9_%D1%84%D1%80%D0%B0%D0%BD%D0%BA)) (см. [график истории абсолютного курса CHF](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#CHF))
# - 1 **Абс** = 38.416 **CLP** ([**Чилийское песо**](https://ru.wikipedia.org/wiki/%D0%A7%D0%B8%D0%BB%D0%B8%D0%B9%D1%81%D0%BA%D0%BE%D0%B5_%D0%BF%D0%B5%D1%81%D0%BE)) (см. [график истории абсолютного курса CLP](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#CLP))
# - 1 **Абс** = 0.343 **CNY** ([**Китайский юань**](https://ru.wikipedia.org/wiki/%D0%9A%D0%B8%D1%82%D0%B0%D0%B9%D1%81%D0%BA%D0%B8%D0%B9_%D1%8E%D0%B0%D0%BD%D1%8C)) (см. [график истории абсолютного курса CNY](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#CNY))
# - 1 **Абс** = 199.958 **COP** ([**Колумбийское песо**](https://ru.wikipedia.org/wiki/%D0%9A%D0%BE%D0%BB%D1%83%D0%BC%D0%B1%D0%B8%D0%B9%D1%81%D0%BA%D0%BE%D0%B5_%D0%BF%D0%B5%D1%81%D0%BE)) (см. [график истории абсолютного курса COP](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#COP))
# - 1 **Абс** = 1.057 **CZK** ([**Чешская крона**](https://ru.wikipedia.org/wiki/%D0%A7%D0%B5%D1%88%D1%81%D0%BA%D0%B0%D1%8F_%D0%BA%D1%80%D0%BE%D0%BD%D0%B0)) (см. [график истории абсолютного курса CZK](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#CZK))
# - 1 **Абс** = 0.33 **DKK** ([**Датская крона**](https://ru.wikipedia.org/wiki/%D0%94%D0%B0%D1%82%D1%81%D0%BA%D0%B0%D1%8F_%D0%BA%D1%80%D0%BE%D0%BD%D0%B0)) (см. [график истории абсолютного курса DKK](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#DKK))
# - 1 **Абс** = 1.475 **EGP** ([**Египетский фунт**](https://ru.wikipedia.org/wiki/%D0%95%D0%B3%D0%B8%D0%BF%D0%B5%D1%82%D1%81%D0%BA%D0%B8%D0%B9_%D1%84%D1%83%D0%BD%D1%82)) (см. [график истории абсолютного курса EGP](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#EGP))
# - 1 **Абс** = 0.044 **EUR** ([**Евро**](https://ru.wikipedia.org/wiki/%D0%95%D0%B2%D1%80%D0%BE)) (см. [график истории абсолютного курса EUR](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#EUR))
# - 1 **Абс** = 0.038 **GBP** ([**Фунт стерлингов**](https://ru.wikipedia.org/wiki/%D0%A4%D1%83%D0%BD%D1%82_%D1%81%D1%82%D0%B5%D1%80%D0%BB%D0%B8%D0%BD%D0%B3%D0%BE%D0%B2)) (см. [график истории абсолютного курса GBP](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#GBP))
# - 1 **Абс** = 0.374 **HKD** ([**Гонконгский доллар**](https://ru.wikipedia.org/wiki/%D0%93%D0%BE%D0%BD%D0%BA%D0%BE%D0%BD%D0%B3%D1%81%D0%BA%D0%B8%D0%B9_%D0%B4%D0%BE%D0%BB%D0%BB%D0%B0%D1%80)) (см. [график истории абсолютного курса HKD](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#HKD))
# - 1 **Абс** = 16.401 **HUF** ([**Венгерский форинт**](https://ru.wikipedia.org/wiki/%D0%A4%D0%BE%D1%80%D0%B8%D0%BD%D1%82)) (см. [график истории абсолютного курса HUF](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#HUF))
# - 1 **Абс** = 712.079 **IDR** ([**Индонезийская рупия**](https://ru.wikipedia.org/wiki/%D0%98%D0%BD%D0%B4%D0%BE%D0%BD%D0%B5%D0%B7%D0%B8%D0%B9%D1%81%D0%BA%D0%B0%D1%8F_%D1%80%D1%83%D0%BF%D0%B8%D1%8F)) (см. [график истории абсолютного курса IDR](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#IDR))
# - 1 **Абс** = 0.17 **ILS** ([**Новый израильский шекель**](https://ru.wikipedia.org/wiki/%D0%9D%D0%BE%D0%B2%D1%8B%D0%B9_%D0%B8%D0%B7%D1%80%D0%B0%D0%B8%D0%BB%D1%8C%D1%81%D0%BA%D0%B8%D0%B9_%D1%88%D0%B5%D0%BA%D0%B5%D0%BB%D1%8C)) (см. [график истории абсолютного курса ILS](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#ILS))
# - 1 **Абс** = 3.935 **INR** ([**Индийская рупия**](https://ru.wikipedia.org/wiki/%D0%98%D0%BD%D0%B4%D0%B8%D0%B9%D1%81%D0%BA%D0%B0%D1%8F_%D1%80%D1%83%D0%BF%D0%B8%D1%8F)) (см. [график истории абсолютного курса INR](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#INR))
# - 1 **Абс** = 6.583 **ISK** ([**Исландская крона**](https://ru.wikipedia.org/wiki/%D0%98%D1%81%D0%BB%D0%B0%D0%BD%D0%B4%D1%81%D0%BA%D0%B0%D1%8F_%D0%BA%D1%80%D0%BE%D0%BD%D0%B0)) (см. [график истории абсолютного курса ISK](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#ISK))
# - 1 **Абс** = 6.702 **JPY** ([**Японская иена**](https://ru.wikipedia.org/wiki/%D0%98%D0%B5%D0%BD%D0%B0)) (см. [график истории абсолютного курса JPY](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#JPY))
# - 1 **Абс** = 61.03 **KRW** ([**Южнокорейская вона**](https://ru.wikipedia.org/wiki/%D0%AE%D0%B6%D0%BD%D0%BE%D0%BA%D0%BE%D1%80%D0%B5%D0%B9%D1%81%D0%BA%D0%B0%D1%8F_%D0%B2%D0%BE%D0%BD%D0%B0)) (см. [график истории абсолютного курса KRW](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#KRW))
# - 1 **Абс** = 0.015 **KWD** ([**Кувейтский динар**](https://ru.wikipedia.org/wiki/%D0%9A%D1%83%D0%B2%D0%B5%D0%B9%D1%82%D1%81%D0%BA%D0%B8%D0%B9_%D0%B4%D0%B8%D0%BD%D0%B0%D1%80)) (см. [график истории абсолютного курса KWD](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#KWD))
# - 1 **Абс** = 21.448 **KZT** ([**Казахстанский тенге**](https://ru.wikipedia.org/wiki/%D0%9A%D0%B0%D0%B7%D0%B0%D1%85%D1%81%D1%82%D0%B0%D0%BD%D1%81%D0%BA%D0%B8%D0%B9_%D1%82%D0%B5%D0%BD%D0%B3%D0%B5)) (см. [график истории абсолютного курса KZT](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#KZT))
# - 1 **Абс** = 0.824 **MXN** ([**Мексиканское песо**](https://ru.wikipedia.org/wiki/%D0%9C%D0%B5%D0%BA%D1%81%D0%B8%D0%BA%D0%B0%D0%BD%D1%81%D0%BA%D0%BE%D0%B5_%D0%BF%D0%B5%D1%81%D0%BE)) (см. [график истории абсолютного курса MXN](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#MXN))
# - 1 **Абс** = 0.221 **MYR** ([**Малайзийский ринггит**](https://ru.wikipedia.org/wiki/%D0%9C%D0%B0%D0%BB%D0%B0%D0%B9%D0%B7%D0%B8%D0%B9%D1%81%D0%BA%D0%B8%D0%B9_%D1%80%D0%B8%D0%BD%D0%B3%D0%B3%D0%B8%D1%82)) (см. [график истории абсолютного курса MYR](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#MYR))
# - 1 **Абс** = 0.509 **NOK** ([**Норвежская крона**](https://ru.wikipedia.org/wiki/%D0%9D%D0%BE%D1%80%D0%B2%D0%B5%D0%B6%D1%81%D0%BA%D0%B0%D1%8F_%D0%BA%D1%80%D0%BE%D0%BD%D0%B0)) (см. [график истории абсолютного курса NOK](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#NOK))
# - 1 **Абс** = 0.078 **NZD** ([**Новозеландский доллар**](https://ru.wikipedia.org/wiki/%D0%9D%D0%BE%D0%B2%D0%BE%D0%B7%D0%B5%D0%BB%D0%B0%D0%BD%D0%B4%D1%81%D0%BA%D0%B8%D0%B9_%D0%B4%D0%BE%D0%BB%D0%BB%D0%B0%D1%80)) (см. [график истории абсолютного курса NZD](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#NZD))
# - 1 **Абс** = 0.174 **PEN** ([**Перуанский новый соль**](https://ru.wikipedia.org/wiki/%D0%9F%D0%B5%D1%80%D1%83%D0%B0%D0%BD%D1%81%D0%BA%D0%B8%D0%B9_%D0%BD%D0%BE%D0%B2%D1%8B%D0%B9_%D1%81%D0%BE%D0%BB%D1%8C)) (см. [график истории абсолютного курса PEN](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#PEN))
# - 1 **Абс** = 2.677 **PHP** ([**Филиппинское песо**](https://ru.wikipedia.org/wiki/%D0%A4%D0%B8%D0%BB%D0%B8%D0%BF%D0%BF%D0%B8%D0%BD%D1%81%D0%BA%D0%BE%D0%B5_%D0%BF%D0%B5%D1%81%D0%BE)) (см. [график истории абсолютного курса PHP](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#PHP))
# - 1 **Абс** = 13.765 **PKR** ([**Пакистанская рупия**](https://ru.wikipedia.org/wiki/%D0%9F%D0%B0%D0%BA%D0%B8%D1%81%D1%82%D0%B0%D0%BD%D1%81%D0%BA%D0%B0%D1%8F_%D1%80%D1%83%D0%BF%D0%B8%D1%8F)) (см. [график истории абсолютного курса PKR](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#PKR))
# - 1 **Абс** = 0.199 **PLN** ([**Польский злотый**](https://ru.wikipedia.org/wiki/%D0%9F%D0%BE%D0%BB%D1%8C%D1%81%D0%BA%D0%B8%D0%B9_%D0%B7%D0%BB%D0%BE%D1%82%D1%8B%D0%B9)) (см. [график истории абсолютного курса PLN](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#PLN))
# - 1 **Абс** = 0.174 **QAR** ([**Катарский риал**](https://ru.wikipedia.org/wiki/%D0%9A%D0%B0%D1%82%D0%B0%D1%80%D1%81%D0%BA%D0%B8%D0%B9_%D1%80%D0%B8%D0%B0%D0%BB)) (см. [график истории абсолютного курса QAR](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#QAR))
# - 1 **Абс** = 0.22 **RON** ([**Румынский лей**](https://ru.wikipedia.org/wiki/%D0%A0%D1%83%D0%BC%D1%8B%D0%BD%D1%81%D0%BA%D0%B8%D0%B9_%D0%BB%D0%B5%D0%B9)) (см. [график истории абсолютного курса RON](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#RON))
# - 1 **Абс** = 4.02 **RUB** ([**Российский рубль**](https://ru.wikipedia.org/wiki/%D0%A0%D0%BE%D1%81%D1%81%D0%B8%D0%B9%D1%81%D0%BA%D0%B8%D0%B9_%D1%80%D1%83%D0%B1%D0%BB%D1%8C)) (см. [график истории абсолютного курса RUB](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#RUB))
# - 1 **Абс** = 0.179 **SAR** ([**Саудовский риял**](https://ru.wikipedia.org/wiki/%D0%A1%D0%B0%D1%83%D0%B4%D0%BE%D0%B2%D1%81%D0%BA%D0%B8%D0%B9_%D1%80%D0%B8%D1%8F%D0%BB)) (см. [график истории абсолютного курса SAR](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#SAR))
# - 1 **Абс** = 0.511 **SEK** ([**Шведская крона**](https://ru.wikipedia.org/wiki/%D0%A8%D0%B2%D0%B5%D0%B4%D1%81%D0%BA%D0%B0%D1%8F_%D0%BA%D1%80%D0%BE%D0%BD%D0%B0)) (см. [график истории абсолютного курса SEK](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#SEK))
# - 1 **Абс** = 0.064 **SGD** ([**Сингапурский доллар**](https://ru.wikipedia.org/wiki/%D0%A1%D0%B8%D0%BD%D0%B3%D0%B0%D0%BF%D1%83%D1%80%D1%81%D0%BA%D0%B8%D0%B9_%D0%B4%D0%BE%D0%BB%D0%BB%D0%B0%D1%80)) (см. [график истории абсолютного курса SGD](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#SGD))
# - 1 **Абс** = 1.655 **THB** ([**Тайский бат**](https://ru.wikipedia.org/wiki/%D0%A2%D0%B0%D0%B9%D1%81%D0%BA%D0%B8%D0%B9_%D0%B1%D0%B0%D1%82)) (см. [график истории абсолютного курса THB](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#THB))
# - 1 **Абс** = 1.128 **TRY** ([**Турецкая лира**](https://ru.wikipedia.org/wiki/%D0%A2%D1%83%D1%80%D0%B5%D1%86%D0%BA%D0%B0%D1%8F_%D0%BB%D0%B8%D1%80%D0%B0)) (см. [график истории абсолютного курса TRY](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#TRY))
# - 1 **Абс** = 1.469 **TWD** ([**Новый тайваньский доллар**](https://ru.wikipedia.org/wiki/%D0%9D%D0%BE%D0%B2%D1%8B%D0%B9_%D1%82%D0%B0%D0%B9%D0%B2%D0%B0%D0%BD%D1%8C%D1%81%D0%BA%D0%B8%D0%B9_%D0%B4%D0%BE%D0%BB%D0%BB%D0%B0%D1%80)) (см. [график истории абсолютного курса TWD](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#TWD))
# - 1 **Абс** = 1.749 **UAH** ([**Украинская гривна**](https://ru.wikipedia.org/wiki/%D0%A3%D0%BA%D1%80%D0%B0%D0%B8%D0%BD%D1%81%D0%BA%D0%B0%D1%8F_%D0%B3%D1%80%D0%B8%D0%B2%D0%BD%D0%B0)) (см. [график истории абсолютного курса UAH](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#UAH))
# - 1 **Абс** = 0.048 **USD** ([**Доллар США**](https://ru.wikipedia.org/wiki/%D0%94%D0%BE%D0%BB%D0%BB%D0%B0%D1%80_%D0%A1%D0%A8%D0%90)) (см. [график истории абсолютного курса USD](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#USD))
# - 1 **Абс** = 1114.342 **VND** ([**Вьетнамский донг**](https://ru.wikipedia.org/wiki/%D0%94%D0%BE%D0%BD%D0%B3)) (см. [график истории абсолютного курса VND](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#VND))
# - 1 **Абс** = 0.89 **ZAR** ([**Южноафриканский рэнд**](https://ru.wikipedia.org/wiki/%D0%AE%D0%B6%D0%BD%D0%BE%D0%B0%D1%84%D1%80%D0%B8%D0%BA%D0%B0%D0%BD%D1%81%D0%BA%D0%B8%D0%B9_%D1%80%D1%8D%D0%BD%D0%B4)) (см. [график истории абсолютного курса ZAR](https://www.kaggle.com/code/eavprog/abscur-hist/notebook#ZAR))
