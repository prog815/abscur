# %% [markdown]
# <a href="https://www.kaggle.com/code/eavprog/abscur-stoimost-absa?scriptVersionId=128061287" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Стоимость Абса
#
# В настоящем проекте принято выражать валюты, акции и другие инструменты по абсолютному курсу, т.е. в Абсах. А сколько стоит один Абс через другие валюты? Для вычисления возьмем и обратим дробь с абсолютным валютным курсом (см. https://www.kaggle.com/eavprog/abscur-posled-kurs).
#
# Например, если мы хотим узнать стоимость одного Абса в долларах, то возьмем курс доллара к Абсу и обратим его: 1 / курс доллара к Абсу. Таким образом, если курс доллара к Абсу равен 20.72, то стоимость одного Абса в долларах будет 0.048 доллара.
#
# Аналогично можно вычислить стоимость Абса в других валютах или инструментах. Например, для вычисления стоимости Абса в евро нужно взять обратный курс евро к Абсу.
#
# Важно учитывать, что курсы валют постоянно меняются и могут быть различными на разных биржах и площадках. При вычислениях стоимости Абса следует использовать актуальные данные о курсах валют и других инструментов.

# %%
import numpy as np
import pandas as pd
import datetime
import abscur_menu
import abscur_post as ap
from IPython.display import Markdown, display

# меню проекта печатаем
abscur_menu.print_menu()

# загрузка истории абсолютных курсов
abscur = pd.read_csv("/kaggle/input/abscur-data/abscur.csv",index_col=0,parse_dates=['Date'])

# загрузка расшифровки валют
ras_cur = pd.read_csv("/kaggle/input/abscur-data/cur_ras.csv",index_col=0)
# Out:
# # Оглавление проекта "Абсолютный валютный курс"
#
# ![Проект "Абсолютный валютный курс"](https://i.ibb.co/cL0D27B/abscur-znak.jpg)
#
# ## Представительства проекта:
# [**БЛОГ**](http://www.abscur.ru) -
# [**VK**](https://vk.com/abscur) -
# [**WhatsApp**](https://chat.whatsapp.com/KrNJXAKizPxDlDSjYfdpQs) -
# [**Viber**](https://invite.viber.com/?g2=AQB63y7Cm%2BNJK0tNZW%2F9kI00M6Wr8HuZ7XeamzN4jZCve8Aq9%2FiD3DY56Eqcf7dc) -
# [**Telegram**](https://t.me/AbsCur) -
# [**ОК**](https://ok.ru/group/53547043520717) -
# [**GitHub**](https://github.com/prog815/abscur) -
# [**YouTube**](https://www.youtube.com/playlist?list=PLG1V24vhSKo6MamGtgm2oTkDZHeHBHNFW) -
# [**Smart-Lab**](https://smart-lab.ru/my/eavpred/) -
# [**VC.ru**](https://vc.ru/u/262921-aleksey-enin) -
# [**Kaggle**](https://www.kaggle.com/code/eavprog/abscur-about)
#
# ## Абсолютные валютные курсы:
# - [О проекте](https://www.kaggle.com/eavprog/abscur-about)
# - [Источник данных с абсолютными курсами](https://www.kaggle.com/code/eavprog/abscur-data)
# - [Последние абсолютные курсы](https://www.kaggle.com/code/eavprog/abscur-posled-kurs)
# - [Графики истории абсолютных валютных курсов](https://www.kaggle.com/eavprog/abscur-hist)
# - [Стоимость Абса](https://www.kaggle.com/eavprog/abscur-stoimost-absa)
# - [Связь валют на графах через корреляцию](https://www.kaggle.com/code/eavprog/abscur-svyas-valut)
# - [Рейтинг абсолютной доходности](https://www.kaggle.com/eavprog/abscur-reyting-dohod)
# - [Рейтинг валют по абсолютным курсам и коэффициенту Шарпа](https://www.kaggle.com/eavprog/abscur-sharp)
# - [Рейтинг абсолютной стабильности валют](https://www.kaggle.com/eavprog/abscur-reit-stabil)
#
# ## Парные валютные курсы
# - [Графики истории парных валютных курсов](https://www.kaggle.com/eavprog/abscur-par-hist)
#
# ## Голубые фишки Московской биржи
# - [Абсолютные курсы голубых фишек Московской биржи](https://www.kaggle.com/code/eavprog/mmvb-abscur-blue-fishki)
# - [Рейтинг голубых фишек Московской биржи по абсолютным курсам и коэффициенту Шарпа](https://www.kaggle.com/code/eavprog/abscur-bluefish-sharp)
# - [Рейтинг голубых фишек Московской биржи по рублевым курсам и коэффициенту Шарпа](https://www.kaggle.com/eavprog/abscur-bluefish-sharp-rub)
#
# ## Товары Московской биржи
# - [Абсолютные курсы товаров Мосбиржи](https://www.kaggle.com/eavprog/mmvb-abscur-tovar)
# - [Рейтинг товаров Московской биржи по коэффициенту Шарпа (долларовый и абсолютный)](https://www.kaggle.com/eavprog/abscur-tovar-sharp)
#
# ---

# %%
names = list(abscur.columns)
names.sort()
text = "# Стоимость Абса на " + datetime.datetime.strftime(abscur.index[-1],"%Y-%m-%d") + "\n\n"
text_post = "Стоимость Абса на " + datetime.datetime.strftime(abscur.index[-1],"%Y-%m-%d") + "\n---\n"
for name in names:
    text += "1 **Абс** = " + str(np.round(1/abscur[name][-1],3)) + " **" + name + "** ([" + ras_cur.loc[name][0] + "](" + ras_cur.loc[name][1]+ "))" + "\n\n"
    text_post += "1 Абс = " + str(np.round(1/abscur[name][-1],3)) + " " + name + " (" + ras_cur.loc[name][0] + ")" + "\n"
display(Markdown(text))
text_post += "---\nИсточник - https://www.kaggle.com/code/eavprog/abscur-stoimost-absa"
ap.send_text(text_post)
# Out:
# # Стоимость Абса на 2023-05-02
#
# 1 **Абс** = 0.177 **AED** ([Дирхам ОАЭ](https://ru.wikipedia.org/wiki/%D0%94%D0%B8%D1%80%D1%85%D0%B0%D0%BC_%D0%9E%D0%90%D0%AD))
#
# 1 **Абс** = 10.73 **ARS** ([Аргентинское песо](https://ru.wikipedia.org/wiki/%D0%90%D1%80%D0%B3%D0%B5%D0%BD%D1%82%D0%B8%D0%BD%D1%81%D0%BA%D0%BE%D0%B5_%D0%BF%D0%B5%D1%81%D0%BE))
#
# 1 **Абс** = 0.073 **AUD** ([Австралийский доллар](https://ru.wikipedia.org/wiki/%D0%90%D0%B2%D1%81%D1%82%D1%80%D0%B0%D0%BB%D0%B8%D0%B9%D1%81%D0%BA%D0%B8%D0%B9_%D0%B4%D0%BE%D0%BB%D0%BB%D0%B0%D1%80))
#
# 1 **Абс** = 0.24 **BRL** ([Бразильский реал](https://ru.wikipedia.org/wiki/%D0%91%D1%80%D0%B0%D0%B7%D0%B8%D0%BB%D1%8C%D1%81%D0%BA%D0%B8%D0%B9_%D1%80%D0%B5%D0%B0%D0%BB))
#
# 1 **Абс** = 0.065 **CAD** ([Канадский доллар](https://ru.wikipedia.org/wiki/%D0%9A%D0%B0%D0%BD%D0%B0%D0%B4%D1%81%D0%BA%D0%B8%D0%B9_%D0%B4%D0%BE%D0%BB%D0%BB%D0%B0%D1%80))
#
# 1 **Абс** = 0.043 **CHF** ([Швейцарский франк](https://ru.wikipedia.org/wiki/%D0%A8%D0%B2%D0%B5%D0%B9%D1%86%D0%B0%D1%80%D1%81%D0%BA%D0%B8%D0%B9_%D1%84%D1%80%D0%B0%D0%BD%D0%BA))
#
# 1 **Абс** = 38.911 **CLP** ([Чилийское песо](https://ru.wikipedia.org/wiki/%D0%A7%D0%B8%D0%BB%D0%B8%D0%B9%D1%81%D0%BA%D0%BE%D0%B5_%D0%BF%D0%B5%D1%81%D0%BE))
#
# 1 **Абс** = 0.333 **CNY** ([Китайский юань](https://ru.wikipedia.org/wiki/%D0%9A%D0%B8%D1%82%D0%B0%D0%B9%D1%81%D0%BA%D0%B8%D0%B9_%D1%8E%D0%B0%D0%BD%D1%8C))
#
# 1 **Абс** = 227.273 **COP** ([Колумбийское песо](https://ru.wikipedia.org/wiki/%D0%9A%D0%BE%D0%BB%D1%83%D0%BC%D0%B1%D0%B8%D0%B9%D1%81%D0%BA%D0%BE%D0%B5_%D0%BF%D0%B5%D1%81%D0%BE))
#
# 1 **Абс** = 1.032 **CZK** ([Чешская крона](https://ru.wikipedia.org/wiki/%D0%A7%D0%B5%D1%88%D1%81%D0%BA%D0%B0%D1%8F_%D0%BA%D1%80%D0%BE%D0%BD%D0%B0))
#
# 1 **Абс** = 0.327 **DKK** ([Датская крона](https://ru.wikipedia.org/wiki/%D0%94%D0%B0%D1%82%D1%81%D0%BA%D0%B0%D1%8F_%D0%BA%D1%80%D0%BE%D0%BD%D0%B0))
#
# 1 **Абс** = 1.486 **EGP** ([Египетский фунт](https://ru.wikipedia.org/wiki/%D0%95%D0%B3%D0%B8%D0%BF%D0%B5%D1%82%D1%81%D0%BA%D0%B8%D0%B9_%D1%84%D1%83%D0%BD%D1%82))
#
# 1 **Абс** = 0.044 **EUR** ([Евро](https://ru.wikipedia.org/wiki/%D0%95%D0%B2%D1%80%D0%BE))
#
# 1 **Абс** = 0.039 **GBP** ([Фунт стерлингов](https://ru.wikipedia.org/wiki/%D0%A4%D1%83%D0%BD%D1%82_%D1%81%D1%82%D0%B5%D1%80%D0%BB%D0%B8%D0%BD%D0%B3%D0%BE%D0%B2))
#
# 1 **Абс** = 0.378 **HKD** ([Гонконгский доллар](https://ru.wikipedia.org/wiki/%D0%93%D0%BE%D0%BD%D0%BA%D0%BE%D0%BD%D0%B3%D1%81%D0%BA%D0%B8%D0%B9_%D0%B4%D0%BE%D0%BB%D0%BB%D0%B0%D1%80))
#
# 1 **Абс** = 16.313 **HUF** ([Венгерский форинт](https://ru.wikipedia.org/wiki/%D0%A4%D0%BE%D1%80%D0%B8%D0%BD%D1%82))
#
# 1 **Абс** = 714.286 **IDR** ([Индонезийская рупия](https://ru.wikipedia.org/wiki/%D0%98%D0%BD%D0%B4%D0%BE%D0%BD%D0%B5%D0%B7%D0%B8%D0%B9%D1%81%D0%BA%D0%B0%D1%8F_%D1%80%D1%83%D0%BF%D0%B8%D1%8F))
#
# 1 **Абс** = 0.174 **ILS** ([Новый израильский шекель](https://ru.wikipedia.org/wiki/%D0%9D%D0%BE%D0%B2%D1%8B%D0%B9_%D0%B8%D0%B7%D1%80%D0%B0%D0%B8%D0%BB%D1%8C%D1%81%D0%BA%D0%B8%D0%B9_%D1%88%D0%B5%D0%BA%D0%B5%D0%BB%D1%8C))
#
# 1 **Абс** = 3.937 **INR** ([Индийская рупия](https://ru.wikipedia.org/wiki/%D0%98%D0%BD%D0%B4%D0%B8%D0%B9%D1%81%D0%BA%D0%B0%D1%8F_%D1%80%D1%83%D0%BF%D0%B8%D1%8F))
#
# 1 **Абс** = 6.562 **ISK** ([Исландская крона](https://ru.wikipedia.org/wiki/%D0%98%D1%81%D0%BB%D0%B0%D0%BD%D0%B4%D1%81%D0%BA%D0%B0%D1%8F_%D0%BA%D1%80%D0%BE%D0%BD%D0%B0))
#
# 1 **Абс** = 6.623 **JPY** ([Японская иена](https://ru.wikipedia.org/wiki/%D0%98%D0%B5%D0%BD%D0%B0))
#
# 1 **Абс** = 64.516 **KRW** ([Южнокорейская вона](https://ru.wikipedia.org/wiki/%D0%AE%D0%B6%D0%BD%D0%BE%D0%BA%D0%BE%D1%80%D0%B5%D0%B9%D1%81%D0%BA%D0%B0%D1%8F_%D0%B2%D0%BE%D0%BD%D0%B0))
#
# 1 **Абс** = 0.015 **KWD** ([Кувейтский динар](https://ru.wikipedia.org/wiki/%D0%9A%D1%83%D0%B2%D0%B5%D0%B9%D1%82%D1%81%D0%BA%D0%B8%D0%B9_%D0%B4%D0%B8%D0%BD%D0%B0%D1%80))
#
# 1 **Абс** = 21.739 **KZT** ([Казахстанский тенге](https://ru.wikipedia.org/wiki/%D0%9A%D0%B0%D0%B7%D0%B0%D1%85%D1%81%D1%82%D0%B0%D0%BD%D1%81%D0%BA%D0%B8%D0%B9_%D1%82%D0%B5%D0%BD%D0%B3%D0%B5))
#
# 1 **Абс** = 0.864 **MXN** ([Мексиканское песо](https://ru.wikipedia.org/wiki/%D0%9C%D0%B5%D0%BA%D1%81%D0%B8%D0%BA%D0%B0%D0%BD%D1%81%D0%BA%D0%BE%D0%B5_%D0%BF%D0%B5%D1%81%D0%BE))
#
# 1 **Абс** = 0.215 **MYR** ([Малайзийский ринггит](https://ru.wikipedia.org/wiki/%D0%9C%D0%B0%D0%BB%D0%B0%D0%B9%D0%B7%D0%B8%D0%B9%D1%81%D0%BA%D0%B8%D0%B9_%D1%80%D0%B8%D0%BD%D0%B3%D0%B3%D0%B8%D1%82))
#
# 1 **Абс** = 0.517 **NOK** ([Норвежская крона](https://ru.wikipedia.org/wiki/%D0%9D%D0%BE%D1%80%D0%B2%D0%B5%D0%B6%D1%81%D0%BA%D0%B0%D1%8F_%D0%BA%D1%80%D0%BE%D0%BD%D0%B0))
#
# 1 **Абс** = 0.078 **NZD** ([Новозеландский доллар](https://ru.wikipedia.org/wiki/%D0%9D%D0%BE%D0%B2%D0%BE%D0%B7%D0%B5%D0%BB%D0%B0%D0%BD%D0%B4%D1%81%D0%BA%D0%B8%D0%B9_%D0%B4%D0%BE%D0%BB%D0%BB%D0%B0%D1%80))
#
# 1 **Абс** = 0.178 **PEN** ([Перуанский новый соль](https://ru.wikipedia.org/wiki/%D0%9F%D0%B5%D1%80%D1%83%D0%B0%D0%BD%D1%81%D0%BA%D0%B8%D0%B9_%D0%BD%D0%BE%D0%B2%D1%8B%D0%B9_%D1%81%D0%BE%D0%BB%D1%8C))
#
# 1 **Абс** = 2.667 **PHP** ([Филиппинское песо](https://ru.wikipedia.org/wiki/%D0%A4%D0%B8%D0%BB%D0%B8%D0%BF%D0%BF%D0%B8%D0%BD%D1%81%D0%BA%D0%BE%D0%B5_%D0%BF%D0%B5%D1%81%D0%BE))
#
# 1 **Абс** = 13.661 **PKR** ([Пакистанская рупия](https://ru.wikipedia.org/wiki/%D0%9F%D0%B0%D0%BA%D0%B8%D1%81%D1%82%D0%B0%D0%BD%D1%81%D0%BA%D0%B0%D1%8F_%D1%80%D1%83%D0%BF%D0%B8%D1%8F))
#
# 1 **Абс** = 0.202 **PLN** ([Польский злотый](https://ru.wikipedia.org/wiki/%D0%9F%D0%BE%D0%BB%D1%8C%D1%81%D0%BA%D0%B8%D0%B9_%D0%B7%D0%BB%D0%BE%D1%82%D1%8B%D0%B9))
#
# 1 **Абс** = 0.175 **QAR** ([Катарский риал](https://ru.wikipedia.org/wiki/%D0%9A%D0%B0%D1%82%D0%B0%D1%80%D1%81%D0%BA%D0%B8%D0%B9_%D1%80%D0%B8%D0%B0%D0%BB))
#
# 1 **Абс** = 0.216 **RON** ([Румынский лей](https://ru.wikipedia.org/wiki/%D0%A0%D1%83%D0%BC%D1%8B%D0%BD%D1%81%D0%BA%D0%B8%D0%B9_%D0%BB%D0%B5%D0%B9))
#
# 1 **Абс** = 3.839 **RUB** ([Российский рубль](https://ru.wikipedia.org/wiki/%D0%A0%D0%BE%D1%81%D1%81%D0%B8%D0%B9%D1%81%D0%BA%D0%B8%D0%B9_%D1%80%D1%83%D0%B1%D0%BB%D1%8C))
#
# 1 **Абс** = 0.181 **SAR** ([Саудовский риял](https://ru.wikipedia.org/wiki/%D0%A1%D0%B0%D1%83%D0%B4%D0%BE%D0%B2%D1%81%D0%BA%D0%B8%D0%B9_%D1%80%D0%B8%D1%8F%D0%BB))
#
# 1 **Абс** = 0.497 **SEK** ([Шведская крона](https://ru.wikipedia.org/wiki/%D0%A8%D0%B2%D0%B5%D0%B4%D1%81%D0%BA%D0%B0%D1%8F_%D0%BA%D1%80%D0%BE%D0%BD%D0%B0))
#
# 1 **Абс** = 0.064 **SGD** ([Сингапурский доллар](https://ru.wikipedia.org/wiki/%D0%A1%D0%B8%D0%BD%D0%B3%D0%B0%D0%BF%D1%83%D1%80%D1%81%D0%BA%D0%B8%D0%B9_%D0%B4%D0%BE%D0%BB%D0%BB%D0%B0%D1%80))
#
# 1 **Абс** = 1.646 **THB** ([Тайский бат](https://ru.wikipedia.org/wiki/%D0%A2%D0%B0%D0%B9%D1%81%D0%BA%D0%B8%D0%B9_%D0%B1%D0%B0%D1%82))
#
# 1 **Абс** = 0.937 **TRY** ([Турецкая лира](https://ru.wikipedia.org/wiki/%D0%A2%D1%83%D1%80%D0%B5%D1%86%D0%BA%D0%B0%D1%8F_%D0%BB%D0%B8%D1%80%D0%B0))
#
# 1 **Абс** = 1.483 **TWD** ([Новый тайваньский доллар](https://ru.wikipedia.org/wiki/%D0%9D%D0%BE%D0%B2%D1%8B%D0%B9_%D1%82%D0%B0%D0%B9%D0%B2%D0%B0%D0%BD%D1%8C%D1%81%D0%BA%D0%B8%D0%B9_%D0%B4%D0%BE%D0%BB%D0%BB%D0%B0%D1%80))
#
# 1 **Абс** = 1.762 **UAH** ([Украинская гривна](https://ru.wikipedia.org/wiki/%D0%A3%D0%BA%D1%80%D0%B0%D0%B8%D0%BD%D1%81%D0%BA%D0%B0%D1%8F_%D0%B3%D1%80%D0%B8%D0%B2%D0%BD%D0%B0))
#
# 1 **Абс** = 0.048 **USD** ([Доллар США](https://ru.wikipedia.org/wiki/%D0%94%D0%BE%D0%BB%D0%BB%D0%B0%D1%80_%D0%A1%D0%A8%D0%90))
#
# 1 **Абс** = 1111.111 **VND** ([Вьетнамский донг](https://ru.wikipedia.org/wiki/%D0%94%D0%BE%D0%BD%D0%B3))
#
# 1 **Абс** = 0.886 **ZAR** ([Южноафриканский рэнд](https://ru.wikipedia.org/wiki/%D0%AE%D0%B6%D0%BD%D0%BE%D0%B0%D1%84%D1%80%D0%B8%D0%BA%D0%B0%D0%BD%D1%81%D0%BA%D0%B8%D0%B9_%D1%80%D1%8D%D0%BD%D0%B4))
